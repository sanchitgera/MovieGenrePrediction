# %% [markdown]
# ## Classical Models

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from skmultilearn.problem_transform import BinaryRelevance
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from nltk import word_tokenize     
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer 
import numpy as np
from sklearn.neural_network import MLPClassifier
from sklearn.multioutput import ClassifierChain

# %%
def load_data(subset = None):
    data = pd.read_csv("./dataset_20000.csv")
    if subset is not None:
        return data.head(subset)
    return data

# %%
def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

# %%
dataset = load_data(subset = 1000)

# %%
stemmer = PorterStemmer()

# %%
class LemmaTokenizer(object):
    def __init__(self):
        self.wnl = WordNetLemmatizer()
    def __call__(self, doc):
        return [self.wnl.lemmatize(t) for t in word_tokenize(doc)]

# %%
def tokenize(text):
    tokens = nltk.word_tokenize(text)
    stems = stem_tokens(tokens, stemmer)
    return stems

# %% [markdown]
# ### Neural Network Classifiers

# %%
x = dataset['summary']
y = dataset.drop(["summary"], axis=1)

cnt_vect = CountVectorizer(stop_words='english', tokenizer=tokenize)
tf_transform = TfidfTransformer()

r = cnt_vect.fit_transform(x)

dense = r.todense()

#for (x,y), value in np.ndenumerate(dense):
#    arr = dense[x]
#    arr[arr > 1] = 1

x = dense

classifier = ClassifierChain(MLPClassifier(hidden_layer_sizes=(30,), activation='logistic', max_iter=1000))

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

model = classifier.fit(x_train, y_train)
predictions = model.predict(x_test)
target_names = dataset.drop(["summary"], axis=1).columns.tolist()
report = classification_report(y_test, predictions, target_names=target_names)

# %%
len(cnt_vect.get_feature_names())
# Out:
# 4543

# %%
print(report)
# Out:
#                  precision    recall  f1-score   support
#
#           Drama       0.67      0.31      0.42        13
#          Comedy       0.00      0.00      0.00         4
#        Thriller       0.00      0.00      0.00         3
#    Romance Film       0.00      0.00      0.00         1
#          Action       0.00      0.00      0.00         3
#          Horror       0.00      0.00      0.00         2
#   Crime Fiction       0.00      0.00      0.00         2
#       Adventure       0.00      0.00      0.00         1
# Science Fiction       0.00      0.00      0.00         2
#       Animation       0.00      0.00      0.00         0
# Romantic comedy       0.00      0.00      0.00         0
#         Mystery       0.00      0.00      0.00         1
#  Crime Thriller       0.00      0.00      0.00         2
#         Fantasy       0.00      0.00      0.00         0
#
#     avg / total       0.25      0.12      0.16        34

# %%
from sklearn.metrics import jaccard_similarity_score

# %%
score = jaccard_similarity_score(y_test, predictions)

# %%
print(score)

# %% [markdown]
# ### KNeighbors Classifier

# %%
classifier = BinaryRelevance(KNeighborsClassifier())

x = dataset['summary']
y = dataset.drop(["summary"], axis=1)

cnt_vect = CountVectorizer(stop_words='english')
tf_transform = TfidfTransformer()

r = cnt_vect.fit_transform(x)
r = tf_transform.fit_transform(r)
x = r

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33)

model = classifier.fit(x_train, y_train)
predictions = model.predict(x_test)
target_names = dataset.drop(["summary"], axis=1).columns.tolist()
report = classification_report(y_test, predictions, target_names=target_names)

# %%
print(report)

# %%
x_train
# Out:
# <3350x45175 sparse matrix of type '<class 'numpy.float64'>'
# 	with 407214 stored elements in Compressed Sparse Row format>

# %%
x = dataset['summary']
y = dataset.drop(["summary"], axis=1)

cnt_vect = CountVectorizer(stop_words='english', tokenizer=LemmaTokenizer())
tf_transform = TfidfTransformer()

r = cnt_vect.fit_transform(x)

# %%
cnt_vect.get_feature_names()
# Out:
# ['!',
#  '#',
#  '$',
#  '%',
#  '&',
#  "'",
#  "''",
#  "'150",
#  "'50s",
#  "'52",
#  "'60s",
#  "'70s",
#  "'72",
#  "'76",
#  "'78",
#  "'80s",
#  "'86",
#  "'88",
#  "'96",
#  "'a",
#  "'admiral",
#  "'adverts",
#  "'all",
#  "'amen",
#  "'an",
#  "'ancient",
#  "'and",
#  "'animals",
#  "'are",
#  "'around",
#  "'at",
#  "'awakens",
#  "'baby",
#  "'bad",
#  "'balkan",
#  "'bananas",
#  "'bare",
#  "'bazza",
#  "'believe",
#  "'better",
#  "'big",
#  "'bilge",
#  "'bill",
#  "'billy",
#  "'bird",
#  "'black",
#  "'blade",
#  "'bleeds",
#  "'blood",
#  "'bloodstone",
#  "'body",
#  "'booky",
#  "'boy",
#  "'brain",
#  "'break",
#  "'bros",
#  "'bug",
#  "'bye",
#  "'cabin",
#  "'caesarion",
#  "'calling",
#  "'camp",
#  "'can't-get-right",
#  "'cannon",
#  "'cause",
#  "'celebrity",
#  "'channel",
#  "'charlie",
#  "'chat",
#  "'chatted",
#  "'child",
#  "'chris",
#  "'citizen",
#  "'clean",
#  "'cloverleaf",
#  "'cobra",
#  "'coincidental",
#  "'collecting",
#  "'communist",
#  "'condi",
#  "'control",
#  "'conveniently",
#  "'cool",
#  "'coping",
#  "'coveney",
#  "'curly",
#  "'d",
#  "'daddy",
#  "'dancing",
#  "'danielle",
#  "'david",
#  "'death",
#  "'defend",
#  "'did",
#  "'die",
#  "'dirty",
#  "'disaster",
#  "'distasteful",
#  "'ditch",
#  "'djinn",
#  "'do",
#  "'doc",
#  "'doctors",
#  "'dog",
#  "'donated",
#  "'doris",
#  "'dr",
#  "'dud",
#  "'duff",
#  "'durango",
#  "'eagle",
#  "'earl",
#  "'earlier",
#  "'ecology",
#  "'educational",
#  "'edwards",
#  "'eh",
#  "'em",
#  "'emotions",
#  "'entities",
#  "'eskimo",
#  "'even",
#  "'everyone",
#  "'executive",
#  "'fang",
#  "'far",
#  "'farmer",
#  "'fathead",
#  "'ferrin",
#  "'films",
#  "'fingers",
#  "'fire",
#  "'fixed",
#  "'fleet",
#  "'football",
#  "'for",
#  "'forgotten",
#  "'fourth",
#  "'framed",
#  "'freaky",
#  "'free",
#  "'friendly-reminder",
#  "'friends",
#  "'fury",
#  "'gene",
#  "'general",
#  "'genius",
#  "'georgie",
#  "'gil",
#  "'go",
#  "'go-between",
#  "'goliath",
#  "'gone",
#  "'good",
#  "'goodfellas",
#  "'graduates",
#  "'great",
#  "'great-aunt",
#  "'green",
#  "'grey",
#  "'grieving",
#  "'grim",
#  "'groovy",
#  "'gun",
#  "'gus",
#  "'handy",
#  "'hansel",
#  "'hard",
#  "'harold",
#  "'harris",
#  "'hawk",
#  "'he",
#  "'head",
#  "'heads",
#  "'heart",
#  "'heavenly",
#  "'help",
#  "'her",
#  "'hetty",
#  "'hey",
#  "'hideout",
#  "'hoist",
#  "'hood",
#  "'hopscotch",
#  "'hounds",
#  "'house",
#  "'housebroken",
#  "'hurl",
#  "'i",
#  "'im",
#  "'impaled",
#  "'in",
#  "'in-crowd",
#  "'interrogation",
#  "'invincible",
#  "'iron",
#  "'jack-a-lympics",
#  "'jackie",
#  "'jamie",
#  "'janitor",
#  "'jarvis",
#  "'job",
#  "'jobs",
#  "'john",
#  "'johnny",
#  "'juiced",
#  "'junior",
#  "'k-pax",
#  "'kill",
#  "'king",
#  "'kit",
#  "'knocking",
#  "'l",
#  "'landlady",
#  "'last",
#  "'laughing",
#  "'liberty",
#  "'lifeless",
#  "'little",
#  "'liv",
#  "'ll",
#  "'lost",
#  "'lucky",
#  "'m",
#  "'maggie",
#  "'manager",
#  "'married",
#  "'mary",
#  "'masked",
#  "'masterpiece",
#  "'medicine",
#  "'mega-trouble",
#  "'michelle",
#  "'midget",
#  "'mike",
#  "'milk",
#  "'minutemen",
#  "'miracle",
#  "'mistake",
#  "'more",
#  "'moved",
#  "'mrs",
#  "'mull",
#  "'must",
#  "'mystery",
#  "'n",
#  "'nanny",
#  "'nature",
#  "'naughty",
#  "'neither",
#  "'nell",
#  "'no",
#  "'normal",
#  "'not",
#  "'nuclear",
#  "'ocho",
#  "'okay",
#  "'one",
#  "'oneness",
#  "'order",
#  "'oregon",
#  "'original",
#  "'oscar",
#  "'out",
#  "'papers",
#  "'pathetic",
#  "'persuaded",
#  "'peyton",
#  "'pimp-king",
#  "'pimps",
#  "'pinafore",
#  "'pink",
#  "'pit",
#  "'plane",
#  "'played",
#  "'poisons",
#  "'portraits",
#  "'post",
#  "'power",
#  "'primitive",
#  "'princess",
#  "'progress",
#  "'promising",
#  "'protector",
#  "'pure",
#  "'quick",
#  "'r",
#  "'re",
#  "'real",
#  "'regulars",
#  "'remembering",
#  "'reprogramming",
#  "'reward",
#  "'round",
#  "'royal",
#  "'rule",
#  "'rust",
#  "'s",
#  "'sapience",
#  "'sarge",
#  "'schani",
#  "'secretly",
#  "'security",
#  "'servant",
#  "'sex",
#  "'sexually",
#  "'share",
#  "'sheilas",
#  "'shopgirl",
#  "'silent",
#  "'sins",
#  "'sister",
#  "'skid",
#  "'slags",
#  "'slagtown",
#  "'slick",
#  "'slipstream",
#  "'sniff",
#  "'snort",
#  "'so",
#  "'sorry",
#  "'south",
#  "'spare",
#  "'special",
#  "'speed",
#  "'spells",
#  "'spic",
#  "'spider",
#  "'squeak",
#  "'squealers",
#  "'staying",
#  "'stiff",
#  "'strange",
#  "'sub-humanoids",
#  "'summoning",
#  "'swan",
#  "'sync",
#  "'synchronicity",
#  "'tabloid",
#  "'take",
#  "'tales",
#  "'tank",
#  "'team",
#  "'thank",
#  "'that",
#  "'the",
#  "'their",
#  "'they",
#  "'théâtre",
#  "'til",
#  "'tilvester",
#  "'tooled",
#  "'toots",
#  "'trip",
#  "'try",
#  "'tsk",
#  "'uncles",
#  "'undesirables",
#  "'until",
#  "'utopia",
#  "'ve",
#  "'vette",
#  "'vx",
#  "'wanted",
#  "'warlock",
#  "'watchmen",
#  "'we",
#  "'white",
#  "'willie",
#  "'willis",
#  "'wonderful",
#  "'work",
#  "'wrasslin",
#  "'x",
#  "'yarvis",
#  "'yes",
#  "'you",
#  "'zombies",
#  '(',
#  '*',
#  '**ah',
#  '**all',
#  '**aye',
#  '**ha',
#  '**lightly',
#  '**merrily',
#  '**ochi',
#  '**of',
#  '**oh',
#  '**onward',
#  '**with',
#  '*a',
#  '*admiral',
#  '*also',
#  '*another',
#  '*betty',
#  '*beverly',
#  '*black',
#  '*buildings',
#  '*captain',
#  '*chapter',
#  '*deleted',
#  '*dwight',
#  '*group',
#  '*honeymooners',
#  '*in',
#  '*jerry',
#  '*joseph',
#  '*jughead',
#  '*linda',
#  '*moira',
#  '*moose',
#  '*mouse',
#  '*mungo',
#  '*nevil',
#  '*pilots',
#  '*sergeant',
#  '*shelley',
#  '*struggling',
#  '*the',
#  '*tindle',
#  '*tori',
#  '*united',
#  '*unlike',
#  '*veronica',
#  '+8',
#  ',',
#  '-',
#  '--',
#  '-2',
#  '-after',
#  '-allen.pdf',
#  '-as',
#  '-before',
#  '-belting',
#  '-bugs',
#  '-class',
#  '-ing',
#  '-style',
#  '-type',
#  '-when',
#  '-–',
#  '-—',
#  '.',
#  '..',
#  '...',
#  '.2.1.5',
#  '.357',
#  '.38',
#  '.45',
#  '.45-60',
#  '.50',
#  '.50-caliber',
#  '.adapted',
#  '.and',
#  '.anna',
#  '.broken',
#  '.buck',
#  '.go',
#  '.http',
#  '.imdb',
#  '.in',
#  '.jack',
#  '.joan',
#  '.lantz.goldenagecartoons.com',
#  '.somewhere',
#  '.threads',
#  '.weiler',
#  '.wide',
#  '.yahoo',
#  '.your',
#  '/',
#  '//articles.latimes.com/1985-02-15/news/mn-3221_1_secret-service-agent-jerry-parr|titlelos',
#  '//bicycling.about.com/od/professionalcycling/fr/bicycle_dreams_review.htm',
#  '//blog.nola.com/mikescott/2007/06/filming_finally_begins_on_blac.html|authorfilming',
#  '//blogs.crikey.com.au/cinetology/2012/03/30/10-terrorists-movie-review-high-voltage-entertainment/|titleluke',
#  '//blogs.indiewire.com/theplaylist/archives/ryan_gosling_calls_upcoming_project_only_god_forgives_the_strangest_thing_h',
#  '//books.google.com/books',
#  '//collider.com/henrys-crime-trailer/80892/',
#  '//data.bls.gov/cgi-bin/cpicalc.pl',
#  '//detour-mag.com/assets/2008/05/02/cult-flick-20th-century-oz/',
#  '//en.wikipedia.org/wiki/spook',
#  '//entertainment.timesonline.co.uk/tol/arts_and_entertainment/film/article4020963.ece|titlemay',
#  '//exclamationmark.wordpress.com/2007/10/26/eyes-of-a-stranger-1981/',
#  '//forum.bcdb.com/forum/gforum.cgi',
#  '//ftvdb.bfi.org.uk/sift/title/28677',
#  '//ftvdb.bfi.org.uk/sift/title/30933',
#  '//ftvdb.bfi.org.uk/sift/title/31380',
#  '//ftvdb.bfi.org.uk/sift/title/32901',
#  '//ftvdb.bfi.org.uk/sift/title/34339',
#  '//ftvdb.bfi.org.uk/sift/title/35250',
#  '//helenair.com/news/local/obituaries/article_b2081642-7e92-11df-81a9-001cc4c03286.html',
#  '//isbndb.com/d/book/alabama_moon.html',
#  '//latimesblogs.latimes.com/movies/2011/09/ed-helms-jason-segel-jeff-who-lives-at-home-duplass-brothers-sarandon-reviews-toronto.html|accessdatethe',
#  '//living.scotsman.com/features/rising-to-the-light.2359793.jp',
#  '//minnesota.publicradio.org/display/web/2010/04/16/my-run/',
#  '//movies.amctv.com/movie/87535/code-of-the-secret-service/overview|titleamc|accessdatehttp',
#  '//movies.nytimes.com/movie/115297/up-the-river/overview|workmovies',
#  '//movies.nytimes.com/movie/123408/always-goodbye/overview',
#  '//movies.nytimes.com/movie/142570/dad-for-a-day/overview',
#  '//movies.nytimes.com/movie/225664/birthday-blues/overview',
#  '//movies.nytimes.com/movie/225666/forgotten-babies/overview',
#  '//movies.nytimes.com/movie/225674/washee-ironee/overview',
#  '//movies.nytimes.com/movie/226187/men-in-fright/overview',
#  '//movies.nytimes.com/movie/226190/time-out-for-lessons/overview',
#  "//movies.nytimes.com/movie/226196/alfalfa's-double/overview",
#  '//movies.nytimes.com/movie/226197/the-big-premiere/overview',
#  "//movies.nytimes.com/movie/226202/waldo's-last-stand/overview",
#  "//movies.nytimes.com/movie/226211/rover's-big-chance/overview",
#  '//movies.nytimes.com/movie/226217/calling-all-kids/overview',
#  '//movies.nytimes.com/movie/25501/it-came-from-beneath-the-sea/overview',
#  '//movies.nytimes.com/movie/53167/wake-of-the-red-witch/overview',
#  '//movies.nytimes.com/movie/53914/the-westerner/overview',
#  '//movies.nytimes.com/movie/review',
#  '//movies.yahoo.com/movie/1808515512/details',
#  '//myrunmovie.com/',
#  '//news.google.com/newspapers',
#  '//news.independent.co.uk/people/profiles/article11293.ece',
#  '//nla.gov.au/nla.news-article41856242',
#  '//othervenicefilmfest.com/program/sun10el.html',
#  '//query.nytimes.com/gst/fullpage.html',
#  '//s-s-v.freehostia.com/98-04/ss_last_exit_04.html',
#  '//sacbee.com/172/story/149603.html',
#  '//smib.vuw.ac.nz:8081/www/anzmac20',
#  '//sports.espn.go.com/espn/page2/story',
#  '//themave.com/cooper/filmog/cowblady2.htm',
#  '//totallyher.com/the-dog-who-saved-christmas-tv-movie-review/',
#  '//tv.zap2it.com/tveditorial/tve_main/1,1002,271',
#  '//www.accessmylibrary.com/article-1g1-147127297/lyme-doctor-ruled-guilty.html',
#  '//www.allmovie.com/',
#  '//www.allmovie.com/movie/fighting-man-of-the-plains-v91372',
#  '//www.allmovie.com/movie/the-end-of-the-affair-v90464',
#  '//www.allmovie.com/movie/the-fear-inside-v16964',
#  '//www.allmovie.com/movie/the-outsider-v276077',
#  '//www.allmovie.com/movie/were-not-married-v53686',
#  '//www.allmovie.com/work/come-on-george-87635',
#  '//www.allmovie.com/work/critics-choice-81937',
#  '//www.allmovie.com/work/in-love-and-war-96395',
#  '//www.allmovie.com/work/none-but-the-lonely-heart-35601',
#  '//www.allmovie.com/work/period-of-adjustment-37763',
#  '//www.allmovie.com/work/stepmonster-46838',
#  '//www.allmovie.com/work/submarine-command-112134',
#  '//www.allmovie.com/work/the-missing-people-102558',
#  '//www.allmovie.com/work/the-piano-mans-daughter-259860',
#  '//www.allmovie.com/work/wild-boy-54528',
#  '//www.allmovie.com/work/yesterday-was-a-lie-430812',
#  '//www.answers.com/topic/make-haste-to-live',
#  '//www.archives.gov/genealogy/heritage/native-american/dawes.html|commission',
#  '//www.army.mil',
#  '//www.awn.com/heaven_and_hell/pal/gp3.htm',
#  '//www.battleplanetmovie.com/synopsis.html',
#  '//www.bbc.co.uk/bbcfilms/film/quartet',
#  '//www.bbc.co.uk/films/2001/03/16/human_traffic_1999_review.shtml|title2010-01-09',
#  '//www.bcdb.com/cartoon/36544-jasper_and_the_haunted_house.html/',
#  '//www.blisstree.com/playlibrary/the-dog-who-saved-christmas/',
#  '//www.blockbusteronline.com/movies/mickeys-once-upon-a-christmas.html',
#  '//www.campcampaign.com/could-the-40-point-plan-work-in-the-real-world/',
#  '//www.cbs.com/primetime/worst_week/bio/kurtwood_smith/bio.php',
#  '//www.clan.org.au/resources-books-details.php',
#  '//www.comingsoon.net/news/movienews.php',
#  '//www.dvdtalk.com/dvdsavant/s92shop.html',
#  '//www.fandango.com/codeofthesecretservice_v87535/summary|titlefandango/rovi',
#  '//www.fandango.com/granpa_v20508/summary',
#  '//www.film.com/movies/truth-about-kerry/14726471',
#  '//www.filmslatemagazine.com/filmmaking/documentary-filmmaking-my-run',
#  '//www.first14.com/bhopal-gas-tragedy-92-injuries-termed-minor-822.html|accessdatefirst14',
#  '//www.forbes.com/forbes/2007/0312/096.html',
#  '//www.gov.im/dti/iomfilm/pastproductions/2008/meandorsonwelles.xml',
#  '//www.hitfix.com/articles/nicole-kidman-to-get-psychological-with-oldboy-director-in-stoker',
#  '//www.hmsrichmond.org/dict_b.htm',
#  '//www.hollywoodreporter.com/news/berlin-2012-brendan-gleeson-chris',
#  '//www.imdb.com/name/nm0532212/',
#  '//www.imdb.com/name/nm0826572/',
#  '//www.imdb.com/title/tt0023512/',
#  '//www.imdb.com/title/tt0028788/plotsummary',
#  '//www.imdb.com/title/tt0032741/',
#  '//www.imdb.com/title/tt0039958/plotsummary',
#  '//www.imdb.com/title/tt0041172',
#  '//www.imdb.com/title/tt0054117/',
#  '//www.imdb.com/title/tt0083900/plotsummary',
#  '//www.imdb.com/title/tt0087837/',
#  '//www.imdb.com/title/tt0101672/plotsummary',
#  '//www.imdb.com/title/tt0107941/plotsummary',
#  '//www.imdb.com/title/tt0151106/',
#  '//www.imdb.com/title/tt0188674/quotes|title2010-01-11',
#  '//www.imdb.com/title/tt0201726/plotsummary',
#  '//www.imdb.com/title/tt0309715/',
#  '//www.imdb.com/title/tt0424880/faq',
#  '//www.imdb.com/title/tt1079444/',
#  '//www.imdb.com/title/tt1377811/plotsummary',
#  '//www.imdb.com/title/tt1673736/',
#  '//www.imdb.com/titles/tt003228/',
#  '//www.independent.ie/lifestyle/education/shakespeare/from-stage-to-screen-1225784.html|titlewhitington|firstnovember',
#  '//www.industrycentral.net/director_interviews/nj01.htm',
#  '//www.jamaica-gleaner.com/gleaner/20090919/ent/ent2.html',
#  '//www.joblo.com/arrow/index.php',
#  '//www.mammothtimes.com/content/view/99365/',
#  '//www.marauder.org/comic32.htm',
#  '//www.news.com.au/couriermail/story/0,23739,24101258-7642,00.html|',
#  '//www.nhpr.org/node/29048',
#  '//www.nytimes.com/2010/01/12/movies/12rohmer.html',
#  '//www.ocscreenwriters.com/',
#  '//www.outcast-films.com/films/cu/background.html',
#  '//www.preview-online.com/s2005/feature_articles/red/index.html',
#  '//www.radaronline.com/exclusives/2008/10/radar-exclusive-move-over-w-condi-is-getting-her-own-movie.php',
#  '//www.rickmcgrath.com/jack_hill_movies/spider_baby.html/',
#  '//www.salon.com/ent/movies/1998/04/10butcher.html',
#  '//www.salon.com/ent/movies/btm/feature/2009/06/20/roundup/index.html',
#  '//www.sdff.org/awardwinners.html',
#  '//www.seinology.com/scripts/script-01.shtml',
#  '//www.sfgenealogy.com/sf/history/hbtbcidx.htm',
#  '//www.tcm.com/tcmdb/title.jsp',
#  '//www.tcm.com/tcmdb/title/80435/kiss-them-for-me/',
#  '//www.tcm.com/tcmdb/title/82288/mad-youth/full-synopsis.html',
#  '//www.tcm.com/tcmdb/title/83590/misbehaving-husbands/',
#  '//www.tcm.com/tcmdb/title/title.jsp',
#  '//www.ten.com.au/ten/joanne-lees-murder-in-the-outback-overview.htm',
#  '//www.theage.com.au/national/tracking-lifes-disasters-20080817-3wx5.html',
#  '//www.theaustralian.news.com.au/story/0,25197,24168396-15803,00.html|',
#  '//www.thefilmlot.com/interviews/intsgordon.php',
#  '//www.thestudiotour.com/ush/backlot/street_colonial_2.html',
#  '//www.time.com/time/magazine/0,9263,7601320815,00.html',
#  '//www.tlavideo.com/details/product_details.cfm',
#  '//www.washingtonpost.com/wp-dyn/content/article/2007/01/19/ar2007011901571.html',
#  '//www.youtube.com/watch',
#  '/c/a/1999/04/09/dd62687.dtl|',
#  '0',
#  '0-385-09079-x',
#  '0-517-16625-9',
#  '0-7566-1033-8',
#  '0-7864-2010-3',
#  '0-7864-4099-6',
#  '0.',
#  '0.08',
#  '0.19',
#  '0.although',
#  '007',
#  '01-04-2009',
#  '02',
#  '0253341531',
#  '03358',
#  '047',
#  '08/01/08',
#  '0813513413.',
#  '0:00',
#  '1',
#  '1,000',
#  '1,000,000',
#  '1,000-mile',
#  '1,000-year',
#  '1,006,600',
#  '1,047,200',
#  '1,049,100',
#  '1,100',
#  '1,200',
#  '1,400',
#  '1,500',
#  '1,500,000',
#  '1-12.',
#  '1-56656-388-7',
#  '1-57806-650-6',
#  '1-9.',
#  '1-minute',
#  '1.',
#  '1.5',
#  '1.98',
#  '1/2',
#  '1/25',
#  '1/5th',
#  '1/6',
#  '10',
#  '10,000',
#  '10,001',
#  '10-footer',
#  '10-minute',
#  '10-piece',
#  '10-speed',
#  '10-year',
#  '10-year-old',
#  '10.',
#  '10.1',
#  '10.69',
#  '10.five',
#  '100',
#  '100+',
#  '100,000',
#  '100,000.',
#  '100.',
#  '1000',
#  '1000-pound',
#  '1000-word',
#  '1000.',
#  '1000.00',
#  '1000—the',
#  '1005',
#  '101st',
#  '1030/1600',
#  '104',
#  '1040',
#  '105',
#  '105-year-old',
#  '106',
#  '109',
#  '10:00',
#  '10:00pm',
#  '10th',
#  '10—usa',
#  '11',
#  '11,000',
#  '11-17',
#  '11-inch',
#  '11-year-old',
#  '11-year-olds',
#  '110',
#  '1100',
#  '110th',
#  '111',
#  '1156',
#  '116',
#  '118.',
#  '11:30',
#  '11am',
#  '11th',
#  '12',
#  '12,000',
#  '12-15',
#  '12-gauge',
#  '12-pounder',
#  '12-sided',
#  '12-year',
#  '12-year-old',
#  '12.',
#  '120,000',
#  '1200',
#  '123',
#  '125',
#  '125-year',
#  '127-year-old',
#  '128',
#  '129',
#  '12:01',
#  '12th',
#  '12—whose',
#  '13',
#  '13,000',
#  '13-year',
#  '13-year-old',
#  '130',
#  '130,000',
#  '130-year',
#  '1300',
#  '131',
#  '1313',
#  '131st',
#  '1330s',
#  '1344',
#  '136-foot',
#  '13th',
#  '14',
#  '14,000',
#  '14-year',
#  '14-year-old',
#  '14.',
#  '140,000',
#  '1408',
#  '1471',
#  '1476',
#  '148',
#  '1482',
#  '14th',
#  '15',
#  '15,000',
#  '15,000,000',
#  '15-13.',
#  '15-frame',
#  '15-year',
#  '15-year-old',
#  '150',
#  '150,000',
#  '150-a-month',
#  '150-foot',
#  '150-mile',
#  '150-year',
#  '1500',
#  '1506',
#  '150th',
#  '1517',
#  '1518.',
#  '1525',
#  '153',
#  '1549.',
#  '1551',
#  '1553.',
#  '1558',
#  '1558.',
#  '158',
#  '159-161',
#  '159.',
#  '15th',
#  '15th-century',
#  '16',
#  '16,000',
#  '16-23',
#  '16-millimeter',
#  '16-year-old',
#  '16.',
#  '160',
#  '160-million-year',
#  '1609',
#  '161',
#  '1611',
#  '1645',
#  '1649',
#  '1657.',
#  '1658.',
#  '1659',
#  '1659.',
#  '1660.',
#  '1673',
#  '1693',
#  '1697',
#  '16mm',
#  '16th',
#  '17',
#  '17-16',
#  '17-minute',
#  '17-year',
#  '17-year-old',
#  '17.80',
#  '1715',
#  '1744',
#  '1745',
#  '175',
#  '1750',
#  '1760s',
#  '1768.',
#  '1773',
#  '1776',
#  '1780',
#  '1780.',
#  '1782',
#  '1784',
#  '1789',
#  '1790',
#  '1793',
#  '1794',
#  '1797',
#  '1799',
#  '17th',
#  '17th-century',
#  '17ththe',
#  '18',
#  '18,000',
#  '18-08-2010',
#  '18-22-year-old',
#  '18-foot',
#  '18-hour',
#  '18-year-old',
#  '18.',
#  '18.7',
#  '180',
#  '180,000',
#  '180.',
#  '180.00',
#  '1800s',
#  '1802',
#  '1808',
#  '1814.',
#  '1815',
#  '1818',
#  '182',
#  '1820',
#  '1821',
#  '1821.',
#  '1824',
#  '1829',
#  '1831',
#  '1834',
#  '1835',
#  '1837',
#  '1838',
#  '1840',
#  '1840s',
#  '1843',
#  '1844',
#  '1844.',
#  '1845.',
#  '1845.ruth',
#  '1846',
#  '1848.',
#  '1849',
#  '1849.wagon',
#  '1850',
#  '1850.',
#  '1851',
#  '1854',
#  '1856',
#  '1857',
#  '186',
#  '1860',
#  '1860s',
#  '1861',
#  '1861.',
#  '1862',
#  '1862.',
#  '1863',
#  '1863.',
#  '1864',
#  '1865',
#  '1866',
#  '1868',
#  '1869',
#  '1869.',
#  '1870',
#  '1870.',
#  '1870s',
#  '1871',
#  '1871.',
#  '1876',
#  '1878',
#  '1879',
#  '1880',
#  '1880s',
#  '1881',
#  '1882',
#  '1884',
#  '1885',
#  '1886',
#  '1887',
#  '1888',
#  '1890',
#  '1890.',
#  '1893',
#  '1893-1914',
#  '1893.',
#  '1894',
#  '1895',
#  '1896',
#  '1897.',
#  '1898',
#  '1899',
#  '1899.',
#  '18th',
#  '18th-century',
#  '18½-minute',
#  '19',
#  '19-year',
#  '19-year-old',
#  '19.',
#  '1900',
#  '1900.',
#  '1900s',
#  '1901.',
#  '1902',
#  '1902.',
#  '1904',
#  '1904.the',
#  '1905',
#  '1906',
#  '1909',
#  '1910',
#  '1910.',
#  '1910s',
#  '1911',
#  '1912',
#  '1912-1956',
#  '1912.',
#  '1913',
#  '1914',
#  '1915',
#  '1916',
#  '1916–1918',
#  '1917',
#  '1917-1928',
#  '1917.',
#  '1918',
#  '1918–1921',
#  '1919',
#  '1919.',
#  '1920',
#  '1920s',
#  '1921',
#  '1921–1923',
#  '1922',
#  '1923',
#  '1923.',
#  '1924',
#  '1924–1931',
#  '1925',
#  '1926',
#  '1927',
#  '1927.',
#  '1928',
#  '1928.',
#  '1929',
#  '1930',
#  '1930s',
#  '1930s-dressed',
#  '1931',
#  '1931–1932',
#  ...]
