# %% [markdown]
# ## Classical Models

# %%
import pandas as pd
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import CountVectorizer
from skmultilearn.problem_transform import BinaryRelevance
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from nltk import word_tokenize     
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer 
from sklearn.multiclass import OneVsRestClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from nltk.corpus import stopwords
from gensim.models import Word2Vec
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import jaccard_similarity_score
import numpy as np

# %%
stop_words = set(stopwords.words('english'))

# %%
def load_data(subset = None):
    data = pd.read_csv("./dataset_20000.csv")
    if subset is not None:
        return data.head(subset)
    return data

# %%
def stem_tokens(tokens, stemmer):
    stemmed = []
    for item in tokens:
        stemmed.append(stemmer.stem(item))
    return stemmed

# %%
dataset = load_data(subset = 5)

# %%
stemmer = PorterStemmer()

# %%
class LemmaTokenizer(object):
    def __init__(self):
        self.wnl = WordNetLemmatizer()
    def __call__(self, doc):
        return [self.wnl.lemmatize(t) for t in word_tokenize(doc)]

# %%
def tokenize(text):
    text = text.lower()
    tokens = nltk.word_tokenize(text)
    filtered = [word for word in tokens if word not in stop_words]
    stems = stem_tokens(filtered, stemmer)
    return stems

# %%
x = dataset["summary"]
y = dataset.drop(["summary"], axis=1)

# %%
def sent_vectorizer(sent, model):
    sent_vec =[]
    numw = 0
    for w in sent:
        try:
            if numw == 0:
                sent_vec = model[w]
            else:
                sent_vec = np.add(sent_vec, model[w])
            numw+=1
        except:
            pass
    
    return np.asarray(sent_vec) / numw

# %%
mapped = x.map(tokenize)
word_model = Word2Vec(mapped, min_count=1)

# %%
word_model.wv.vocab
# Out:
# {'tenur': <gensim.models.keyedvectors.Vocab at 0x7f2826cc6a20>,
#  'waster': <gensim.models.keyedvectors.Vocab at 0x7f28263fd400>,
#  'membership': <gensim.models.keyedvectors.Vocab at 0x7f282e43cd30>,
#  'faux-italian': <gensim.models.keyedvectors.Vocab at 0x7f28263fdeb8>,
#  'subvert': <gensim.models.keyedvectors.Vocab at 0x7f28263fd780>,
#  'amaz': <gensim.models.keyedvectors.Vocab at 0x7f28263fd898>,
#  'froze': <gensim.models.keyedvectors.Vocab at 0x7f28263fdcf8>,
#  'facial': <gensim.models.keyedvectors.Vocab at 0x7f28263fd7f0>,
#  'infantri': <gensim.models.keyedvectors.Vocab at 0x7f28263fd438>,
#  'devast': <gensim.models.keyedvectors.Vocab at 0x7f28263fd6a0>,
#  'bureau': <gensim.models.keyedvectors.Vocab at 0x7f2826246f60>,
#  'bowl': <gensim.models.keyedvectors.Vocab at 0x7f28263fd908>,
#  'cart': <gensim.models.keyedvectors.Vocab at 0x7f28263fde10>,
#  'obstacl': <gensim.models.keyedvectors.Vocab at 0x7f28263fd7b8>,
#  'infest': <gensim.models.keyedvectors.Vocab at 0x7f28263fddd8>,
#  'male': <gensim.models.keyedvectors.Vocab at 0x7f28263fdcc0>,
#  'helen': <gensim.models.keyedvectors.Vocab at 0x7f28263fda58>,
#  'confisc': <gensim.models.keyedvectors.Vocab at 0x7f28263fdf28>,
#  'skateboard': <gensim.models.keyedvectors.Vocab at 0x7f282e447c88>,
#  'hole': <gensim.models.keyedvectors.Vocab at 0x7f2826380978>,
#  'repetit': <gensim.models.keyedvectors.Vocab at 0x7f2826380c88>,
#  'chimera': <gensim.models.keyedvectors.Vocab at 0x7f2826380668>,
#  'stomp': <gensim.models.keyedvectors.Vocab at 0x7f2826380a58>,
#  'zaibatsu': <gensim.models.keyedvectors.Vocab at 0x7f2826380908>,
#  'ratisbon': <gensim.models.keyedvectors.Vocab at 0x7f2826380198>,
#  'blackout': <gensim.models.keyedvectors.Vocab at 0x7f28263805f8>,
#  'strict': <gensim.models.keyedvectors.Vocab at 0x7f28263803c8>,
#  'archaeolog': <gensim.models.keyedvectors.Vocab at 0x7f2826380e10>,
#  'vice': <gensim.models.keyedvectors.Vocab at 0x7f2826380320>,
#  'curse.lot': <gensim.models.keyedvectors.Vocab at 0x7f2826380940>,
#  'slogan': <gensim.models.keyedvectors.Vocab at 0x7f28263804a8>,
#  'remembr': <gensim.models.keyedvectors.Vocab at 0x7f28263806a0>,
#  'eyepatch': <gensim.models.keyedvectors.Vocab at 0x7f2826381908>,
#  'ascend': <gensim.models.keyedvectors.Vocab at 0x7f2826381160>,
#  'countless': <gensim.models.keyedvectors.Vocab at 0x7f2826381978>,
#  'crimes.http': <gensim.models.keyedvectors.Vocab at 0x7f2826381390>,
#  'beani': <gensim.models.keyedvectors.Vocab at 0x7f2826381358>,
#  'fightin': <gensim.models.keyedvectors.Vocab at 0x7f2826381c18>,
#  'esteban': <gensim.models.keyedvectors.Vocab at 0x7f28263816a0>,
#  'la/spca': <gensim.models.keyedvectors.Vocab at 0x7f28263816d8>,
#  'beanstalk': <gensim.models.keyedvectors.Vocab at 0x7f2826381320>,
#  'iri': <gensim.models.keyedvectors.Vocab at 0x7f28263817f0>,
#  'outpac': <gensim.models.keyedvectors.Vocab at 0x7f282e448fd0>,
#  'gunn': <gensim.models.keyedvectors.Vocab at 0x7f28263818d0>,
#  'celebratori': <gensim.models.keyedvectors.Vocab at 0x7f2826381e48>,
#  'dous': <gensim.models.keyedvectors.Vocab at 0x7f28263810b8>,
#  'hamilton': <gensim.models.keyedvectors.Vocab at 0x7f28263814a8>,
#  'bustier': <gensim.models.keyedvectors.Vocab at 0x7f2826381438>,
#  'bishop': <gensim.models.keyedvectors.Vocab at 0x7f282e462400>,
#  'miranova': <gensim.models.keyedvectors.Vocab at 0x7f2826381e10>,
#  'felt': <gensim.models.keyedvectors.Vocab at 0x7f2826381208>,
#  'react': <gensim.models.keyedvectors.Vocab at 0x7f2826381a90>,
#  'egg': <gensim.models.keyedvectors.Vocab at 0x7f2826381c88>,
#  'code': <gensim.models.keyedvectors.Vocab at 0x7f282e45e320>,
#  'campground': <gensim.models.keyedvectors.Vocab at 0x7f28263f9f60>,
#  'rafael': <gensim.models.keyedvectors.Vocab at 0x7f28263f9f28>,
#  'surround': <gensim.models.keyedvectors.Vocab at 0x7f28263f9ef0>,
#  'inchoat': <gensim.models.keyedvectors.Vocab at 0x7f28263f9eb8>,
#  'à': <gensim.models.keyedvectors.Vocab at 0x7f2826390518>,
#  "'handi": <gensim.models.keyedvectors.Vocab at 0x7f2826250cc0>,
#  'conspir': <gensim.models.keyedvectors.Vocab at 0x7f28263904a8>,
#  'fragment': <gensim.models.keyedvectors.Vocab at 0x7f2826390c18>,
#  'remain': <gensim.models.keyedvectors.Vocab at 0x7f28263908d0>,
#  'dem': <gensim.models.keyedvectors.Vocab at 0x7f2826390d68>,
#  'phelp': <gensim.models.keyedvectors.Vocab at 0x7f2826390390>,
#  'heartbroken': <gensim.models.keyedvectors.Vocab at 0x7f28263900b8>,
#  'brownston': <gensim.models.keyedvectors.Vocab at 0x7f2826390ac8>,
#  'aka': <gensim.models.keyedvectors.Vocab at 0x7f2826390198>,
#  '1649': <gensim.models.keyedvectors.Vocab at 0x7f2826390fd0>,
#  'veda': <gensim.models.keyedvectors.Vocab at 0x7f282630a518>,
#  'estevez': <gensim.models.keyedvectors.Vocab at 0x7f28263907f0>,
#  'theme-rel': <gensim.models.keyedvectors.Vocab at 0x7f2826390ef0>,
#  'superstar': <gensim.models.keyedvectors.Vocab at 0x7f28263905f8>,
#  'paulett': <gensim.models.keyedvectors.Vocab at 0x7f2826394128>,
#  'gasp': <gensim.models.keyedvectors.Vocab at 0x7f2826394f98>,
#  'statur': <gensim.models.keyedvectors.Vocab at 0x7f2826394780>,
#  'swanson': <gensim.models.keyedvectors.Vocab at 0x7f282e460860>,
#  'pen/lov': <gensim.models.keyedvectors.Vocab at 0x7f2826394550>,
#  'toppl': <gensim.models.keyedvectors.Vocab at 0x7f28263b6d30>,
#  'getaway': <gensim.models.keyedvectors.Vocab at 0x7f2826394438>,
#  'pointy-nos': <gensim.models.keyedvectors.Vocab at 0x7f2826394320>,
#  'standard': <gensim.models.keyedvectors.Vocab at 0x7f28263b6eb8>,
#  'trigger-happi': <gensim.models.keyedvectors.Vocab at 0x7f2826394e48>,
#  'successor': <gensim.models.keyedvectors.Vocab at 0x7f2826394240>,
#  'off-season': <gensim.models.keyedvectors.Vocab at 0x7f2826308c88>,
#  'transact': <gensim.models.keyedvectors.Vocab at 0x7f2826250da0>,
#  'high-fli': <gensim.models.keyedvectors.Vocab at 0x7f282633f710>,
#  '851': <gensim.models.keyedvectors.Vocab at 0x7f2826394be0>,
#  'plainsboro': <gensim.models.keyedvectors.Vocab at 0x7f28263945c0>,
#  'musclebound': <gensim.models.keyedvectors.Vocab at 0x7f2826394da0>,
#  'cliff': <gensim.models.keyedvectors.Vocab at 0x7f2826250dd8>,
#  'epilogu': <gensim.models.keyedvectors.Vocab at 0x7f2826394cc0>,
#  'globe': <gensim.models.keyedvectors.Vocab at 0x7f2826341278>,
#  'mexico': <gensim.models.keyedvectors.Vocab at 0x7f2826394048>,
#  'assail': <gensim.models.keyedvectors.Vocab at 0x7f28263946d8>,
#  'eagerli': <gensim.models.keyedvectors.Vocab at 0x7f2826394470>,
#  'lobotom': <gensim.models.keyedvectors.Vocab at 0x7f28263941d0>,
#  'podium': <gensim.models.keyedvectors.Vocab at 0x7f2826394f28>,
#  'grisli': <gensim.models.keyedvectors.Vocab at 0x7f28263944e0>,
#  'brian': <gensim.models.keyedvectors.Vocab at 0x7f28263948d0>,
#  'cardin': <gensim.models.keyedvectors.Vocab at 0x7f2826341c50>,
#  'titular': <gensim.models.keyedvectors.Vocab at 0x7f2826394160>,
#  'voicemail': <gensim.models.keyedvectors.Vocab at 0x7f2826341d68>,
#  'moreov': <gensim.models.keyedvectors.Vocab at 0x7f28263940f0>,
#  'manufactur': <gensim.models.keyedvectors.Vocab at 0x7f282e44f668>,
#  'giant': <gensim.models.keyedvectors.Vocab at 0x7f2826394eb8>,
#  'voodoo': <gensim.models.keyedvectors.Vocab at 0x7f2826394080>,
#  'buffalo': <gensim.models.keyedvectors.Vocab at 0x7f2826394208>,
#  '*veronica': <gensim.models.keyedvectors.Vocab at 0x7f28263c6320>,
#  'unlik': <gensim.models.keyedvectors.Vocab at 0x7f28263c6588>,
#  'rebel': <gensim.models.keyedvectors.Vocab at 0x7f28263c62e8>,
#  'sacr': <gensim.models.keyedvectors.Vocab at 0x7f28263c69b0>,
#  'fatal': <gensim.models.keyedvectors.Vocab at 0x7f28263c6550>,
#  'six': <gensim.models.keyedvectors.Vocab at 0x7f2826250eb8>,
#  'broodingli': <gensim.models.keyedvectors.Vocab at 0x7f28263c6b70>,
#  'prone': <gensim.models.keyedvectors.Vocab at 0x7f282639f470>,
#  'ecstat': <gensim.models.keyedvectors.Vocab at 0x7f282639f6d8>,
#  'bennett': <gensim.models.keyedvectors.Vocab at 0x7f282639f828>,
#  'temptress': <gensim.models.keyedvectors.Vocab at 0x7f282639f898>,
#  'advanc': <gensim.models.keyedvectors.Vocab at 0x7f282639fa90>,
#  'medic': <gensim.models.keyedvectors.Vocab at 0x7f282639fc18>,
#  'punish': <gensim.models.keyedvectors.Vocab at 0x7f282639fcc0>,
#  'coomb': <gensim.models.keyedvectors.Vocab at 0x7f282639ff60>,
#  'sycamor': <gensim.models.keyedvectors.Vocab at 0x7f282639f390>,
#  'foster': <gensim.models.keyedvectors.Vocab at 0x7f282639f9e8>,
#  'bostanescu': <gensim.models.keyedvectors.Vocab at 0x7f282639fcf8>,
#  'mortar': <gensim.models.keyedvectors.Vocab at 0x7f2826235320>,
#  'linemen': <gensim.models.keyedvectors.Vocab at 0x7f282639f7f0>,
#  'reassur': <gensim.models.keyedvectors.Vocab at 0x7f282639fb00>,
#  'pull': <gensim.models.keyedvectors.Vocab at 0x7f282639fb70>,
#  'leopardess': <gensim.models.keyedvectors.Vocab at 0x7f282639f358>,
#  'golf-cours': <gensim.models.keyedvectors.Vocab at 0x7f282639f668>,
#  'boyfriend': <gensim.models.keyedvectors.Vocab at 0x7f2826250f60>,
#  'melchett': <gensim.models.keyedvectors.Vocab at 0x7f282639ff98>,
#  'air': <gensim.models.keyedvectors.Vocab at 0x7f282639f550>,
#  'becki': <gensim.models.keyedvectors.Vocab at 0x7f282639f978>,
#  'gonzal': <gensim.models.keyedvectors.Vocab at 0x7f282639f9b0>,
#  'airedal': <gensim.models.keyedvectors.Vocab at 0x7f282639fac8>,
#  'unspecifi': <gensim.models.keyedvectors.Vocab at 0x7f282639f4a8>,
#  'meanest': <gensim.models.keyedvectors.Vocab at 0x7f282639f710>,
#  'kalia': <gensim.models.keyedvectors.Vocab at 0x7f282639feb8>,
#  'juic': <gensim.models.keyedvectors.Vocab at 0x7f282e46b550>,
#  'namehttp': <gensim.models.keyedvectors.Vocab at 0x7f282639ff28>,
#  'barnabi': <gensim.models.keyedvectors.Vocab at 0x7f28262ece48>,
#  'manipul': <gensim.models.keyedvectors.Vocab at 0x7f2826308f98>,
#  'evelyn': <gensim.models.keyedvectors.Vocab at 0x7f282639f6a0>,
#  'subson': <gensim.models.keyedvectors.Vocab at 0x7f282639fa58>,
#  'intercours': <gensim.models.keyedvectors.Vocab at 0x7f282634c6d8>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x7f282639f2e8>,
#  'spice': <gensim.models.keyedvectors.Vocab at 0x7f2826252080>,
#  'cult': <gensim.models.keyedvectors.Vocab at 0x7f282639f7b8>,
#  '1871': <gensim.models.keyedvectors.Vocab at 0x7f282639f5f8>,
#  'walk': <gensim.models.keyedvectors.Vocab at 0x7f282639fbe0>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x7f282639fd30>,
#  '666': <gensim.models.keyedvectors.Vocab at 0x7f282639f240>,
#  'brilliant': <gensim.models.keyedvectors.Vocab at 0x7f282639f588>,
#  'undeclar': <gensim.models.keyedvectors.Vocab at 0x7f282639f8d0>,
#  'intersect': <gensim.models.keyedvectors.Vocab at 0x7f282639fef0>,
#  'crew': <gensim.models.keyedvectors.Vocab at 0x7f282639f198>,
#  'vest': <gensim.models.keyedvectors.Vocab at 0x7f282639f2b0>,
#  'cyborg': <gensim.models.keyedvectors.Vocab at 0x7f282639f438>,
#  '1:00': <gensim.models.keyedvectors.Vocab at 0x7f282639f3c8>,
#  'southsid': <gensim.models.keyedvectors.Vocab at 0x7f282639f940>,
#  'apollo': <gensim.models.keyedvectors.Vocab at 0x7f282639f208>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x7f282639f278>,
#  'ascent': <gensim.models.keyedvectors.Vocab at 0x7f282634f860>,
#  'self-humili': <gensim.models.keyedvectors.Vocab at 0x7f28262520f0>,
#  'churchil': <gensim.models.keyedvectors.Vocab at 0x7f282639fc50>,
#  'grate': <gensim.models.keyedvectors.Vocab at 0x7f282639fe10>,
#  'wolf-out': <gensim.models.keyedvectors.Vocab at 0x7f282639fe80>,
#  'trash': <gensim.models.keyedvectors.Vocab at 0x7f282639f4e0>,
#  'vengeanc': <gensim.models.keyedvectors.Vocab at 0x7f282e460208>,
#  'chitti': <gensim.models.keyedvectors.Vocab at 0x7f282639f630>,
#  'denton': <gensim.models.keyedvectors.Vocab at 0x7f282639fe48>,
#  'jez': <gensim.models.keyedvectors.Vocab at 0x7f282639f908>,
#  'greer': <gensim.models.keyedvectors.Vocab at 0x7f282639fc88>,
#  'see': <gensim.models.keyedvectors.Vocab at 0x7f2826252160>,
#  'scari': <gensim.models.keyedvectors.Vocab at 0x7f282639ffd0>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x7f282630a128>,
#  'short-ear': <gensim.models.keyedvectors.Vocab at 0x7f28263a1320>,
#  'still-defi': <gensim.models.keyedvectors.Vocab at 0x7f28263a16a0>,
#  'wayward': <gensim.models.keyedvectors.Vocab at 0x7f28263a1278>,
#  'barku': <gensim.models.keyedvectors.Vocab at 0x7f2826352da0>,
#  'cheap': <gensim.models.keyedvectors.Vocab at 0x7f28263a14a8>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x7f28263a13c8>,
#  'lawman': <gensim.models.keyedvectors.Vocab at 0x7f2826354128>,
#  'juror': <gensim.models.keyedvectors.Vocab at 0x7f282e4378d0>,
#  'pakistani': <gensim.models.keyedvectors.Vocab at 0x7f28263a1198>,
#  'fishbowl': <gensim.models.keyedvectors.Vocab at 0x7f2826354400>,
#  'mcrubi': <gensim.models.keyedvectors.Vocab at 0x7f28263a12b0>,
#  'hosplitaz': <gensim.models.keyedvectors.Vocab at 0x7f28263a12e8>,
#  'portland': <gensim.models.keyedvectors.Vocab at 0x7f28263a1470>,
#  'heil': <gensim.models.keyedvectors.Vocab at 0x7f28263a1438>,
#  'nobil': <gensim.models.keyedvectors.Vocab at 0x7f28263a1518>,
#  'bevi': <gensim.models.keyedvectors.Vocab at 0x7f28263a1550>,
#  'lawn': <gensim.models.keyedvectors.Vocab at 0x7f28263a15f8>,
#  'unconci': <gensim.models.keyedvectors.Vocab at 0x7f282630a240>,
#  'morecamb': <gensim.models.keyedvectors.Vocab at 0x7f28263a11d0>,
#  'nearli': <gensim.models.keyedvectors.Vocab at 0x7f282e44d7b8>,
#  'evolv': <gensim.models.keyedvectors.Vocab at 0x7f28263a14e0>,
#  'po': <gensim.models.keyedvectors.Vocab at 0x7f28263a10b8>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x7f28263a1160>,
#  'extort': <gensim.models.keyedvectors.Vocab at 0x7f28263a1240>,
#  'restroom': <gensim.models.keyedvectors.Vocab at 0x7f28263a1400>,
#  'dover': <gensim.models.keyedvectors.Vocab at 0x7f28263a1630>,
#  'fish': <gensim.models.keyedvectors.Vocab at 0x7f28263a1048>,
#  'repercuss': <gensim.models.keyedvectors.Vocab at 0x7f28263a1358>,
#  'phillip': <gensim.models.keyedvectors.Vocab at 0x7f28263a1080>,
#  'accomplish': <gensim.models.keyedvectors.Vocab at 0x7f28263a1128>,
#  'unborn': <gensim.models.keyedvectors.Vocab at 0x7f282e46b978>,
#  'befriend': <gensim.models.keyedvectors.Vocab at 0x7f28263cf0b8>,
#  '666.': <gensim.models.keyedvectors.Vocab at 0x7f2826357fd0>,
#  'groundless': <gensim.models.keyedvectors.Vocab at 0x7f28263cf3c8>,
#  'goblin': <gensim.models.keyedvectors.Vocab at 0x7f28263cf588>,
#  'snippet': <gensim.models.keyedvectors.Vocab at 0x7f282e46ba90>,
#  'astrid': <gensim.models.keyedvectors.Vocab at 0x7f28263cf470>,
#  'safe': <gensim.models.keyedvectors.Vocab at 0x7f2826252320>,
#  'sociopath': <gensim.models.keyedvectors.Vocab at 0x7f28263cf198>,
#  "n'play": <gensim.models.keyedvectors.Vocab at 0x7f28263cfda0>,
#  'isl': <gensim.models.keyedvectors.Vocab at 0x7f28263cfc88>,
#  'rais': <gensim.models.keyedvectors.Vocab at 0x7f28263cfeb8>,
#  'projector': <gensim.models.keyedvectors.Vocab at 0x7f28263cf358>,
#  '1984': <gensim.models.keyedvectors.Vocab at 0x7f28263cf908>,
#  'failur': <gensim.models.keyedvectors.Vocab at 0x7f28263ade10>,
#  'belfast': <gensim.models.keyedvectors.Vocab at 0x7f28263ade80>,
#  'highland': <gensim.models.keyedvectors.Vocab at 0x7f28263adf98>,
#  'barney': <gensim.models.keyedvectors.Vocab at 0x7f282e44ec18>,
#  'documentari': <gensim.models.keyedvectors.Vocab at 0x7f28262523c8>,
#  'realiti': <gensim.models.keyedvectors.Vocab at 0x7f28263add68>,
#  'caus': <gensim.models.keyedvectors.Vocab at 0x7f28263addd8>,
#  'lorri': <gensim.models.keyedvectors.Vocab at 0x7f28263adeb8>,
#  'pak': <gensim.models.keyedvectors.Vocab at 0x7f28263ade48>,
#  'robberi': <gensim.models.keyedvectors.Vocab at 0x7f28263adf28>,
#  'soap': <gensim.models.keyedvectors.Vocab at 0x7f282635cf98>,
#  'marachek': <gensim.models.keyedvectors.Vocab at 0x7f28263911d0>,
#  'disparagingli': <gensim.models.keyedvectors.Vocab at 0x7f2826391080>,
#  'earliest': <gensim.models.keyedvectors.Vocab at 0x7f282e4426a0>,
#  'brodi': <gensim.models.keyedvectors.Vocab at 0x7f28263912b0>,
#  'film': <gensim.models.keyedvectors.Vocab at 0x7f2826252400>,
#  'versa': <gensim.models.keyedvectors.Vocab at 0x7f282630a438>,
#  'rile': <gensim.models.keyedvectors.Vocab at 0x7f2826391240>,
#  'choke': <gensim.models.keyedvectors.Vocab at 0x7f28263910b8>,
#  'kzl-303': <gensim.models.keyedvectors.Vocab at 0x7f2826391278>,
#  'compli': <gensim.models.keyedvectors.Vocab at 0x7f28262355f8>,
#  'welfar': <gensim.models.keyedvectors.Vocab at 0x7f282e45e048>,
#  'nuclear-pow': <gensim.models.keyedvectors.Vocab at 0x7f282e43a630>,
#  'pitchfork': <gensim.models.keyedvectors.Vocab at 0x7f282635ff28>,
#  'two-fac': <gensim.models.keyedvectors.Vocab at 0x7f28263c7828>,
#  'jewish': <gensim.models.keyedvectors.Vocab at 0x7f28263c7240>,
#  'emil': <gensim.models.keyedvectors.Vocab at 0x7f28263c7630>,
#  'newman': <gensim.models.keyedvectors.Vocab at 0x7f28263c75f8>,
#  'writer': <gensim.models.keyedvectors.Vocab at 0x7f28263c7668>,
#  'telekinet': <gensim.models.keyedvectors.Vocab at 0x7f282630a4a8>,
#  'geoffrey': <gensim.models.keyedvectors.Vocab at 0x7f28263c7eb8>,
#  'undersecretari': <gensim.models.keyedvectors.Vocab at 0x7f28263c7c88>,
#  'profici': <gensim.models.keyedvectors.Vocab at 0x7f28263c70f0>,
#  'hugh': <gensim.models.keyedvectors.Vocab at 0x7f28263c7358>,
#  'addison': <gensim.models.keyedvectors.Vocab at 0x7f28263c77f0>,
#  'crescent': <gensim.models.keyedvectors.Vocab at 0x7f28263c74a8>,
#  'jennif': <gensim.models.keyedvectors.Vocab at 0x7f28262356a0>,
#  'cozi': <gensim.models.keyedvectors.Vocab at 0x7f282e405b70>,
#  'jaunti': <gensim.models.keyedvectors.Vocab at 0x7f28263c7160>,
#  '2005': <gensim.models.keyedvectors.Vocab at 0x7f28263c7be0>,
#  'conflict': <gensim.models.keyedvectors.Vocab at 0x7f28263c79e8>,
#  'burnham': <gensim.models.keyedvectors.Vocab at 0x7f28263c7a20>,
#  'bangin': <gensim.models.keyedvectors.Vocab at 0x7f2826365e48>,
#  'pedest': <gensim.models.keyedvectors.Vocab at 0x7f282639b6d8>,
#  'vine-cov': <gensim.models.keyedvectors.Vocab at 0x7f282639bbe0>,
#  'borgesa': <gensim.models.keyedvectors.Vocab at 0x7f282639be80>,
#  'upcom': <gensim.models.keyedvectors.Vocab at 0x7f282639b128>,
#  'nomad': <gensim.models.keyedvectors.Vocab at 0x7f282639b390>,
#  'sat': <gensim.models.keyedvectors.Vocab at 0x7f28263147f0>,
#  ',': <gensim.models.keyedvectors.Vocab at 0x7f282639b550>,
#  'graciou': <gensim.models.keyedvectors.Vocab at 0x7f2826252518>,
#  'onlook': <gensim.models.keyedvectors.Vocab at 0x7f282639b860>,
#  'backer': <gensim.models.keyedvectors.Vocab at 0x7f282639bb38>,
#  'pheasant': <gensim.models.keyedvectors.Vocab at 0x7f282639bc18>,
#  'ik': <gensim.models.keyedvectors.Vocab at 0x7f282639bef0>,
#  'british': <gensim.models.keyedvectors.Vocab at 0x7f282639be48>,
#  'plate': <gensim.models.keyedvectors.Vocab at 0x7f2826252550>,
#  'demolit': <gensim.models.keyedvectors.Vocab at 0x7f282639b0b8>,
#  'arena': <gensim.models.keyedvectors.Vocab at 0x7f282639b278>,
#  'stepsist': <gensim.models.keyedvectors.Vocab at 0x7f282639b4a8>,
#  'tied-up': <gensim.models.keyedvectors.Vocab at 0x7f282639b7b8>,
#  'fubar': <gensim.models.keyedvectors.Vocab at 0x7f28263b6160>,
#  'ambit': <gensim.models.keyedvectors.Vocab at 0x7f282639ba58>,
#  'lakeb': <gensim.models.keyedvectors.Vocab at 0x7f282639bcf8>,
#  'hypersexu': <gensim.models.keyedvectors.Vocab at 0x7f282639bda0>,
#  '3000.': <gensim.models.keyedvectors.Vocab at 0x7f282639bfd0>,
#  'fackler': <gensim.models.keyedvectors.Vocab at 0x7f282639b240>,
#  'ferret': <gensim.models.keyedvectors.Vocab at 0x7f282639b438>,
#  'whomev': <gensim.models.keyedvectors.Vocab at 0x7f282639b5f8>,
#  'dragnet-typ': <gensim.models.keyedvectors.Vocab at 0x7f282636d080>,
#  'keeslar': <gensim.models.keyedvectors.Vocab at 0x7f282639bac8>,
#  'rees': <gensim.models.keyedvectors.Vocab at 0x7f282639bcc0>,
#  'phallic-shap': <gensim.models.keyedvectors.Vocab at 0x7f282639bf98>,
#  'filthi': <gensim.models.keyedvectors.Vocab at 0x7f282639e048>,
#  'ramsey': <gensim.models.keyedvectors.Vocab at 0x7f282639e128>,
#  'phone': <gensim.models.keyedvectors.Vocab at 0x7f282639e1d0>,
#  'lucif': <gensim.models.keyedvectors.Vocab at 0x7f282639e240>,
#  'emphysema': <gensim.models.keyedvectors.Vocab at 0x7f282639e2b0>,
#  'peterson': <gensim.models.keyedvectors.Vocab at 0x7f282639e390>,
#  'miranda': <gensim.models.keyedvectors.Vocab at 0x7f282639e5c0>,
#  'streetbal': <gensim.models.keyedvectors.Vocab at 0x7f282639e5f8>,
#  'motion': <gensim.models.keyedvectors.Vocab at 0x7f282639e6d8>,
#  'chosen': <gensim.models.keyedvectors.Vocab at 0x7f282639e780>,
#  'minuet': <gensim.models.keyedvectors.Vocab at 0x7f282639e8d0>,
#  'scoutmast': <gensim.models.keyedvectors.Vocab at 0x7f282639ea58>,
#  'religion': <gensim.models.keyedvectors.Vocab at 0x7f282639ec18>,
#  'duc': <gensim.models.keyedvectors.Vocab at 0x7f282639ec50>,
#  'geographi': <gensim.models.keyedvectors.Vocab at 0x7f282639ec88>,
#  'grin': <gensim.models.keyedvectors.Vocab at 0x7f282639eeb8>,
#  'on-track': <gensim.models.keyedvectors.Vocab at 0x7f282639ef98>,
#  'penetr': <gensim.models.keyedvectors.Vocab at 0x7f282639e160>,
#  'unnatur': <gensim.models.keyedvectors.Vocab at 0x7f282639e208>,
#  'aphrodisiac': <gensim.models.keyedvectors.Vocab at 0x7f282639e2e8>,
#  'raze': <gensim.models.keyedvectors.Vocab at 0x7f282639e3c8>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x7f282639e518>,
#  'crane': <gensim.models.keyedvectors.Vocab at 0x7f282639e710>,
#  'chinatown': <gensim.models.keyedvectors.Vocab at 0x7f282639e908>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x7f282639e978>,
#  'archer': <gensim.models.keyedvectors.Vocab at 0x7f282639ea20>,
#  'polka': <gensim.models.keyedvectors.Vocab at 0x7f282e3fd748>,
#  'astound': <gensim.models.keyedvectors.Vocab at 0x7f282639ea90>,
#  'everyon': <gensim.models.keyedvectors.Vocab at 0x7f282639eb70>,
#  'rear': <gensim.models.keyedvectors.Vocab at 0x7f2826252710>,
#  'necessit': <gensim.models.keyedvectors.Vocab at 0x7f282639ee10>,
#  'indispos': <gensim.models.keyedvectors.Vocab at 0x7f282639eef0>,
#  'summer': <gensim.models.keyedvectors.Vocab at 0x7f282639ef60>,
#  'yorkalthough': <gensim.models.keyedvectors.Vocab at 0x7f282639e0b8>,
#  'choic': <gensim.models.keyedvectors.Vocab at 0x7f282639e0f0>,
#  '12': <gensim.models.keyedvectors.Vocab at 0x7f282639e198>,
#  'ceil': <gensim.models.keyedvectors.Vocab at 0x7f282639e320>,
#  'refund': <gensim.models.keyedvectors.Vocab at 0x7f282639e630>,
#  'debt': <gensim.models.keyedvectors.Vocab at 0x7f282639e7f0>,
#  'forev': <gensim.models.keyedvectors.Vocab at 0x7f282639e828>,
#  'archdeacon': <gensim.models.keyedvectors.Vocab at 0x7f282639e9b0>,
#  'rivera': <gensim.models.keyedvectors.Vocab at 0x7f282639eac8>,
#  'weaponri': <gensim.models.keyedvectors.Vocab at 0x7f282639eba8>,
#  'intellectu': <gensim.models.keyedvectors.Vocab at 0x7f282e440898>,
#  'fozzi': <gensim.models.keyedvectors.Vocab at 0x7f282639ecc0>,
#  'burger': <gensim.models.keyedvectors.Vocab at 0x7f282639ed68>,
#  'promiscu': <gensim.models.keyedvectors.Vocab at 0x7f282639ee48>,
#  'schoolmat': <gensim.models.keyedvectors.Vocab at 0x7f282e3fb320>,
#  'dug': <gensim.models.keyedvectors.Vocab at 0x7f2826235a20>,
#  'climax': <gensim.models.keyedvectors.Vocab at 0x7f2826375e80>,
#  'hacienda': <gensim.models.keyedvectors.Vocab at 0x7f282639e358>,
#  'whichev': <gensim.models.keyedvectors.Vocab at 0x7f282639e400>,
#  'basqu': <gensim.models.keyedvectors.Vocab at 0x7f2826378908>,
#  'transport': <gensim.models.keyedvectors.Vocab at 0x7f282639e4a8>,
#  'toadstool': <gensim.models.keyedvectors.Vocab at 0x7f2826378d68>,
#  '1996': <gensim.models.keyedvectors.Vocab at 0x7f282639e588>,
#  'inconveni': <gensim.models.keyedvectors.Vocab at 0x7f282639e668>,
#  'eberli': <gensim.models.keyedvectors.Vocab at 0x7f282639e6a0>,
#  'disinherit': <gensim.models.keyedvectors.Vocab at 0x7f282639e748>,
#  'clerk': <gensim.models.keyedvectors.Vocab at 0x7f282639e7b8>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7f282639e860>,
#  '55': <gensim.models.keyedvectors.Vocab at 0x7f282639e898>,
#  'landon': <gensim.models.keyedvectors.Vocab at 0x7f282639e940>,
#  'accost': <gensim.models.keyedvectors.Vocab at 0x7f282639eb00>,
#  'woodi': <gensim.models.keyedvectors.Vocab at 0x7f282637a710>,
#  'muscular': <gensim.models.keyedvectors.Vocab at 0x7f282639ed30>,
#  'egotist': <gensim.models.keyedvectors.Vocab at 0x7f282639eda0>,
#  'knee': <gensim.models.keyedvectors.Vocab at 0x7f2826235b00>,
#  'darkest': <gensim.models.keyedvectors.Vocab at 0x7f28263a0278>,
#  'disastr': <gensim.models.keyedvectors.Vocab at 0x7f28263a0438>,
#  'zola': <gensim.models.keyedvectors.Vocab at 0x7f28263a04a8>,
#  'cinesound': <gensim.models.keyedvectors.Vocab at 0x7f28263a07b8>,
#  'brigadi': <gensim.models.keyedvectors.Vocab at 0x7f28263a0908>,
#  'spectat': <gensim.models.keyedvectors.Vocab at 0x7f28263a0940>,
#  'months-long': <gensim.models.keyedvectors.Vocab at 0x7f282637d400>,
#  'chime': <gensim.models.keyedvectors.Vocab at 0x7f28263a0198>,
#  'mariann': <gensim.models.keyedvectors.Vocab at 0x7f28263a02b0>,
#  'girlfriend': <gensim.models.keyedvectors.Vocab at 0x7f28263a0358>,
#  'crusad': <gensim.models.keyedvectors.Vocab at 0x7f282637d7f0>,
#  'readi': <gensim.models.keyedvectors.Vocab at 0x7f28263a0668>,
#  'maggenti': <gensim.models.keyedvectors.Vocab at 0x7f282637d978>,
#  'capsiz': <gensim.models.keyedvectors.Vocab at 0x7f282e44eac8>,
#  'captain': <gensim.models.keyedvectors.Vocab at 0x7f28263a0da0>,
#  'troubl': <gensim.models.keyedvectors.Vocab at 0x7f28263a00b8>,
#  'out-of-work': <gensim.models.keyedvectors.Vocab at 0x7f282639f160>,
#  'immedi': <gensim.models.keyedvectors.Vocab at 0x7f28263a0240>,
#  'cartel': <gensim.models.keyedvectors.Vocab at 0x7f28263a0c88>,
#  'helplessli': <gensim.models.keyedvectors.Vocab at 0x7f28263a0cf8>,
#  'differ': <gensim.models.keyedvectors.Vocab at 0x7f28263a0048>,
#  'detach': <gensim.models.keyedvectors.Vocab at 0x7f28263a04e0>,
#  'romeo': <gensim.models.keyedvectors.Vocab at 0x7f2826300898>,
#  'i.': <gensim.models.keyedvectors.Vocab at 0x7f28263a0978>,
#  'jazz': <gensim.models.keyedvectors.Vocab at 0x7f28263a0a20>,
#  'seinfeld': <gensim.models.keyedvectors.Vocab at 0x7f28262b09e8>,
#  'caribbean': <gensim.models.keyedvectors.Vocab at 0x7f282630a978>,
#  'cossack': <gensim.models.keyedvectors.Vocab at 0x7f28263a0be0>,
#  'ballet-styl': <gensim.models.keyedvectors.Vocab at 0x7f28263fa0f0>,
#  'fee': <gensim.models.keyedvectors.Vocab at 0x7f28263fa080>,
#  'though': <gensim.models.keyedvectors.Vocab at 0x7f28263fa2b0>,
#  'holden': <gensim.models.keyedvectors.Vocab at 0x7f28263fa278>,
#  'voorhe': <gensim.models.keyedvectors.Vocab at 0x7f28263fa1d0>,
#  'bultitud': <gensim.models.keyedvectors.Vocab at 0x7f28263fa128>,
#  'furnitur': <gensim.models.keyedvectors.Vocab at 0x7f28263fa048>,
#  'rugbi': <gensim.models.keyedvectors.Vocab at 0x7f28263fa320>,
#  'hard-work': <gensim.models.keyedvectors.Vocab at 0x7f28263fa358>,
#  'meatpack': <gensim.models.keyedvectors.Vocab at 0x7f28263b0e80>,
#  'alic': <gensim.models.keyedvectors.Vocab at 0x7f28262a0940>,
#  'offens': <gensim.models.keyedvectors.Vocab at 0x7f28263b0fd0>,
#  'mud': <gensim.models.keyedvectors.Vocab at 0x7f28263b0dd8>,
#  'bizarr': <gensim.models.keyedvectors.Vocab at 0x7f28263b0e10>,
#  'platon': <gensim.models.keyedvectors.Vocab at 0x7f28263b0e48>,
#  'prize': <gensim.models.keyedvectors.Vocab at 0x7f28263b0ef0>,
#  'covent': <gensim.models.keyedvectors.Vocab at 0x7f28263b0f28>,
#  'bra': <gensim.models.keyedvectors.Vocab at 0x7f28263b0f60>,
#  'bonesaw': <gensim.models.keyedvectors.Vocab at 0x7f28263b0f98>,
#  'antipsychot': <gensim.models.keyedvectors.Vocab at 0x7f2826252b00>,
#  'ito': <gensim.models.keyedvectors.Vocab at 0x7f28263b1080>,
#  'neighbour': <gensim.models.keyedvectors.Vocab at 0x7f282e471710>,
#  'overweight': <gensim.models.keyedvectors.Vocab at 0x7f282e44a6a0>,
#  'diver': <gensim.models.keyedvectors.Vocab at 0x7f28263b1128>,
#  'unlucki': <gensim.models.keyedvectors.Vocab at 0x7f28263b1320>,
#  'racism': <gensim.models.keyedvectors.Vocab at 0x7f2826252b38>,
#  'josi': <gensim.models.keyedvectors.Vocab at 0x7f28263b1400>,
#  'newborn': <gensim.models.keyedvectors.Vocab at 0x7f2826235cf8>,
#  'unrecogn': <gensim.models.keyedvectors.Vocab at 0x7f28263b10b8>,
#  'nebbish': <gensim.models.keyedvectors.Vocab at 0x7f28263b1160>,
#  'brawl': <gensim.models.keyedvectors.Vocab at 0x7f28263b1198>,
#  'banner': <gensim.models.keyedvectors.Vocab at 0x7f28263b11d0>,
#  'slesing': <gensim.models.keyedvectors.Vocab at 0x7f2826341710>,
#  'gamin': <gensim.models.keyedvectors.Vocab at 0x7f28263b1240>,
#  'mercyhurst': <gensim.models.keyedvectors.Vocab at 0x7f28263b1278>,
#  'crepsley': <gensim.models.keyedvectors.Vocab at 0x7f28263b12b0>,
#  'henceforth': <gensim.models.keyedvectors.Vocab at 0x7f28263b12e8>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x7f28263b1358>,
#  'doorbel': <gensim.models.keyedvectors.Vocab at 0x7f2826308710>,
#  'ex-wif': <gensim.models.keyedvectors.Vocab at 0x7f28263fc550>,
#  'girolamo': <gensim.models.keyedvectors.Vocab at 0x7f28263fc588>,
#  'geraldin': <gensim.models.keyedvectors.Vocab at 0x7f28263fc4a8>,
#  'dumbfound': <gensim.models.keyedvectors.Vocab at 0x7f28263fc438>,
#  'myer': <gensim.models.keyedvectors.Vocab at 0x7f28263fc358>,
#  'mistak': <gensim.models.keyedvectors.Vocab at 0x7f28263fc390>,
#  'harrington': <gensim.models.keyedvectors.Vocab at 0x7f28263fc518>,
#  'bunni': <gensim.models.keyedvectors.Vocab at 0x7f28263fc5c0>,
#  'littlefoot': <gensim.models.keyedvectors.Vocab at 0x7f28263fc470>,
#  'babysit': <gensim.models.keyedvectors.Vocab at 0x7f282e441f98>,
#  'brother': <gensim.models.keyedvectors.Vocab at 0x7f28263fc4e0>,
#  'underground': <gensim.models.keyedvectors.Vocab at 0x7f28263fc320>,
#  'preparatori': <gensim.models.keyedvectors.Vocab at 0x7f28263fc2e8>,
#  '1972.': <gensim.models.keyedvectors.Vocab at 0x7f282e447898>,
#  'unwilling': <gensim.models.keyedvectors.Vocab at 0x7f28263b6198>,
#  'narab': <gensim.models.keyedvectors.Vocab at 0x7f28263b6208>,
#  '1971.': <gensim.models.keyedvectors.Vocab at 0x7f28263b6240>,
#  'magazin': <gensim.models.keyedvectors.Vocab at 0x7f28263b6278>,
#  'thermal': <gensim.models.keyedvectors.Vocab at 0x7f28263b62b0>,
#  'sandi': <gensim.models.keyedvectors.Vocab at 0x7f28263b6320>,
#  'boarding-hous': <gensim.models.keyedvectors.Vocab at 0x7f28263b6358>,
#  'anti-semit': <gensim.models.keyedvectors.Vocab at 0x7f28263b6390>,
#  'feroci': <gensim.models.keyedvectors.Vocab at 0x7f28263b63c8>,
#  'suppli': <gensim.models.keyedvectors.Vocab at 0x7f28263b6400>,
#  'bewild': <gensim.models.keyedvectors.Vocab at 0x7f28263b6438>,
#  'hair': <gensim.models.keyedvectors.Vocab at 0x7f28263b6470>,
#  'anita': <gensim.models.keyedvectors.Vocab at 0x7f28262a7898>,
#  'influenc': <gensim.models.keyedvectors.Vocab at 0x7f28263b64a8>,
#  'off-road': <gensim.models.keyedvectors.Vocab at 0x7f28263b64e0>,
#  'melt': <gensim.models.keyedvectors.Vocab at 0x7f28263b6518>,
#  'hatr': <gensim.models.keyedvectors.Vocab at 0x7f28263b6550>,
#  "'david": <gensim.models.keyedvectors.Vocab at 0x7f28263b6588>,
#  'arizona/california': <gensim.models.keyedvectors.Vocab at 0x7f28263b65c0>,
#  'dian': <gensim.models.keyedvectors.Vocab at 0x7f28263b65f8>,
#  'typic': <gensim.models.keyedvectors.Vocab at 0x7f282c0ea208>,
#  'tortur': <gensim.models.keyedvectors.Vocab at 0x7f28263b6630>,
#  'circle.jim': <gensim.models.keyedvectors.Vocab at 0x7f28263b6668>,
#  'paraphras': <gensim.models.keyedvectors.Vocab at 0x7f28263b66a0>,
#  'b-25': <gensim.models.keyedvectors.Vocab at 0x7f28263b66d8>,
#  'wartim': <gensim.models.keyedvectors.Vocab at 0x7f28263b6710>,
#  'glass': <gensim.models.keyedvectors.Vocab at 0x7f28263b6748>,
#  'probabl': <gensim.models.keyedvectors.Vocab at 0x7f28262ee9b0>,
#  'obstin': <gensim.models.keyedvectors.Vocab at 0x7f28263b67b8>,
#  'idol': <gensim.models.keyedvectors.Vocab at 0x7f28263b67f0>,
#  'estrada': <gensim.models.keyedvectors.Vocab at 0x7f28263b6828>,
#  'william': <gensim.models.keyedvectors.Vocab at 0x7f28263b6860>,
#  'petit': <gensim.models.keyedvectors.Vocab at 0x7f28263b6898>,
#  'connelli': <gensim.models.keyedvectors.Vocab at 0x7f28263b68d0>,
#  'despond': <gensim.models.keyedvectors.Vocab at 0x7f282e461978>,
#  'fastbal': <gensim.models.keyedvectors.Vocab at 0x7f28263b6908>,
#  'fireplac': <gensim.models.keyedvectors.Vocab at 0x7f28263b6940>,
#  'siberia': <gensim.models.keyedvectors.Vocab at 0x7f282e3fb908>,
#  'templ': <gensim.models.keyedvectors.Vocab at 0x7f282628ae10>,
#  'dare': <gensim.models.keyedvectors.Vocab at 0x7f282c193048>,
#  'mooseport': <gensim.models.keyedvectors.Vocab at 0x7f28263b69b0>,
#  'angi': <gensim.models.keyedvectors.Vocab at 0x7f28263b69e8>,
#  'vendor': <gensim.models.keyedvectors.Vocab at 0x7f28263b6a20>,
#  'denver': <gensim.models.keyedvectors.Vocab at 0x7f2826252eb8>,
#  'magic': <gensim.models.keyedvectors.Vocab at 0x7f28263b6a90>,
#  '1861.': <gensim.models.keyedvectors.Vocab at 0x7f28263b6ac8>,
#  'jovial': <gensim.models.keyedvectors.Vocab at 0x7f28263b6b00>,
#  'monro': <gensim.models.keyedvectors.Vocab at 0x7f28262f3080>,
#  'rig': <gensim.models.keyedvectors.Vocab at 0x7f28263b6b38>,
#  'holli': <gensim.models.keyedvectors.Vocab at 0x7f282630acc0>,
#  'biplan': <gensim.models.keyedvectors.Vocab at 0x7f28263b6be0>,
#  'absorb': <gensim.models.keyedvectors.Vocab at 0x7f28263b6c18>,
#  'energet': <gensim.models.keyedvectors.Vocab at 0x7f28263b6c50>,
#  'r.': <gensim.models.keyedvectors.Vocab at 0x7f28263b6c88>,
#  'max': <gensim.models.keyedvectors.Vocab at 0x7f28263b6cc0>,
#  'prophesi': <gensim.models.keyedvectors.Vocab at 0x7f28263b6cf8>,
#  'fidget': <gensim.models.keyedvectors.Vocab at 0x7f28263942b0>,
#  'vietnam': <gensim.models.keyedvectors.Vocab at 0x7f28263b6da0>,
#  'new-found': <gensim.models.keyedvectors.Vocab at 0x7f28263b6dd8>,
#  'guidanc': <gensim.models.keyedvectors.Vocab at 0x7f28263b6e10>,
#  'motorbik': <gensim.models.keyedvectors.Vocab at 0x7f28263b6e80>,
#  'jet': <gensim.models.keyedvectors.Vocab at 0x7f2826394c50>,
#  'hung-ov': <gensim.models.keyedvectors.Vocab at 0x7f28263b6ef0>,
#  'placement': <gensim.models.keyedvectors.Vocab at 0x7f28263b6f28>,
#  'suchin': <gensim.models.keyedvectors.Vocab at 0x7f28263b6f60>,
#  'incarcer': <gensim.models.keyedvectors.Vocab at 0x7f28263b6f98>,
#  'baylor': <gensim.models.keyedvectors.Vocab at 0x7f282e4015c0>,
#  'herebi': <gensim.models.keyedvectors.Vocab at 0x7f282631d128>,
#  'unstopp': <gensim.models.keyedvectors.Vocab at 0x7f282633f080>,
#  'diego': <gensim.models.keyedvectors.Vocab at 0x7f282633f0b8>,
#  "'play": <gensim.models.keyedvectors.Vocab at 0x7f282633f0f0>,
#  'stedman': <gensim.models.keyedvectors.Vocab at 0x7f282633f128>,
#  'ore': <gensim.models.keyedvectors.Vocab at 0x7f282633f160>,
#  'morbid': <gensim.models.keyedvectors.Vocab at 0x7f282633f198>,
#  'deeper': <gensim.models.keyedvectors.Vocab at 0x7f282633f1d0>,
#  'labrador': <gensim.models.keyedvectors.Vocab at 0x7f282633f278>,
#  'slipperi': <gensim.models.keyedvectors.Vocab at 0x7f282633f2b0>,
#  'consider': <gensim.models.keyedvectors.Vocab at 0x7f282633f2e8>,
#  'xma': <gensim.models.keyedvectors.Vocab at 0x7f282633f358>,
#  'mcbain': <gensim.models.keyedvectors.Vocab at 0x7f28262560f0>,
#  'fourth-floor': <gensim.models.keyedvectors.Vocab at 0x7f282633f400>,
#  'gunpoint': <gensim.models.keyedvectors.Vocab at 0x7f282633f438>,
#  'cement': <gensim.models.keyedvectors.Vocab at 0x7f282633f470>,
#  'nichola': <gensim.models.keyedvectors.Vocab at 0x7f282633f4a8>,
#  'honcho': <gensim.models.keyedvectors.Vocab at 0x7f282e3fba20>,
#  'homili': <gensim.models.keyedvectors.Vocab at 0x7f282633f4e0>,
#  'namast': <gensim.models.keyedvectors.Vocab at 0x7f282633f518>,
#  'disc': <gensim.models.keyedvectors.Vocab at 0x7f282633f550>,
#  'web|lastbill|titlehttp': <gensim.models.keyedvectors.Vocab at 0x7f282633f588>,
#  'misus': <gensim.models.keyedvectors.Vocab at 0x7f282633f5c0>,
#  'bloodi': <gensim.models.keyedvectors.Vocab at 0x7f282633f5f8>,
#  'rucker': <gensim.models.keyedvectors.Vocab at 0x7f282633f630>,
#  'bypass': <gensim.models.keyedvectors.Vocab at 0x7f282633f668>,
#  'waft': <gensim.models.keyedvectors.Vocab at 0x7f282633f6a0>,
#  'markova': <gensim.models.keyedvectors.Vocab at 0x7f282633f6d8>,
#  'choreograph': <gensim.models.keyedvectors.Vocab at 0x7f2826394198>,
#  'brent': <gensim.models.keyedvectors.Vocab at 0x7f282633f780>,
#  'smitten': <gensim.models.keyedvectors.Vocab at 0x7f282633f7b8>,
#  're-appear': <gensim.models.keyedvectors.Vocab at 0x7f282e464da0>,
#  '2,000,000': <gensim.models.keyedvectors.Vocab at 0x7f282633f7f0>,
#  'flyswatt': <gensim.models.keyedvectors.Vocab at 0x7f282633f828>,
#  'petri': <gensim.models.keyedvectors.Vocab at 0x7f282633f860>,
#  'philip': <gensim.models.keyedvectors.Vocab at 0x7f282633f898>,
#  'unusu': <gensim.models.keyedvectors.Vocab at 0x7f282633f8d0>,
#  'cover': <gensim.models.keyedvectors.Vocab at 0x7f282633f908>,
#  'nose': <gensim.models.keyedvectors.Vocab at 0x7f282633f940>,
#  'conclus': <gensim.models.keyedvectors.Vocab at 0x7f282633f978>,
#  'hum': <gensim.models.keyedvectors.Vocab at 0x7f282633f9b0>,
#  'stair': <gensim.models.keyedvectors.Vocab at 0x7f2826214b70>,
#  'charmain': <gensim.models.keyedvectors.Vocab at 0x7f282633f9e8>,
#  'hockey': <gensim.models.keyedvectors.Vocab at 0x7f282633fa20>,
#  'logan': <gensim.models.keyedvectors.Vocab at 0x7f282633fa58>,
#  'water-damag': <gensim.models.keyedvectors.Vocab at 0x7f282633fa90>,
#  'clifton': <gensim.models.keyedvectors.Vocab at 0x7f282633fac8>,
#  '16': <gensim.models.keyedvectors.Vocab at 0x7f282633fb00>,
#  'raven': <gensim.models.keyedvectors.Vocab at 0x7f282e3ff6d8>,
#  'super-s': <gensim.models.keyedvectors.Vocab at 0x7f282633fb38>,
#  'selkirk': <gensim.models.keyedvectors.Vocab at 0x7f282633fb70>,
#  'grotto': <gensim.models.keyedvectors.Vocab at 0x7f28262e44e0>,
#  'robe': <gensim.models.keyedvectors.Vocab at 0x7f282633fba8>,
#  'dine': <gensim.models.keyedvectors.Vocab at 0x7f2826238278>,
#  'intergalact': <gensim.models.keyedvectors.Vocab at 0x7f282633fc18>,
#  'petersburg': <gensim.models.keyedvectors.Vocab at 0x7f282633fc88>,
#  'conscious': <gensim.models.keyedvectors.Vocab at 0x7f282633fcc0>,
#  'hong': <gensim.models.keyedvectors.Vocab at 0x7f282627f1d0>,
#  'brigand': <gensim.models.keyedvectors.Vocab at 0x7f282633fd30>,
#  'vandergeld': <gensim.models.keyedvectors.Vocab at 0x7f282e443a58>,
#  'ironclad': <gensim.models.keyedvectors.Vocab at 0x7f282633fd68>,
#  'correct': <gensim.models.keyedvectors.Vocab at 0x7f282633fda0>,
#  'attain': <gensim.models.keyedvectors.Vocab at 0x7f282633fdd8>,
#  'bartend': <gensim.models.keyedvectors.Vocab at 0x7f282633fe10>,
#  'famili': <gensim.models.keyedvectors.Vocab at 0x7f282633fe48>,
#  'dangl': <gensim.models.keyedvectors.Vocab at 0x7f28262562e8>,
#  'seatbelt': <gensim.models.keyedvectors.Vocab at 0x7f282e461438>,
#  'unruli': <gensim.models.keyedvectors.Vocab at 0x7f282633fef0>,
#  'awar': <gensim.models.keyedvectors.Vocab at 0x7f282e442e80>,
#  'elli': <gensim.models.keyedvectors.Vocab at 0x7f282633ff60>,
#  'dugg': <gensim.models.keyedvectors.Vocab at 0x7f282633ff98>,
#  'squat': <gensim.models.keyedvectors.Vocab at 0x7f282633ffd0>,
#  'wildli': <gensim.models.keyedvectors.Vocab at 0x7f2826341048>,
#  'trunk': <gensim.models.keyedvectors.Vocab at 0x7f2826341080>,
#  "'we": <gensim.models.keyedvectors.Vocab at 0x7f28263410b8>,
#  'burn': <gensim.models.keyedvectors.Vocab at 0x7f2826341128>,
#  'donald': <gensim.models.keyedvectors.Vocab at 0x7f282630d0f0>,
#  'opera': <gensim.models.keyedvectors.Vocab at 0x7f2826341198>,
#  'handcuf': <gensim.models.keyedvectors.Vocab at 0x7f28263411d0>,
#  'rosen': <gensim.models.keyedvectors.Vocab at 0x7f2826341240>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x7f28263412b0>,
#  'suit': <gensim.models.keyedvectors.Vocab at 0x7f28263412e8>,
#  'louveni': <gensim.models.keyedvectors.Vocab at 0x7f2826341320>,
#  'nun': <gensim.models.keyedvectors.Vocab at 0x7f2826341390>,
#  'adob': <gensim.models.keyedvectors.Vocab at 0x7f28262e9dd8>,
#  '21st': <gensim.models.keyedvectors.Vocab at 0x7f2826341400>,
#  'asham': <gensim.models.keyedvectors.Vocab at 0x7f2826330cf8>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x7f282e44d240>,
#  'bedford': <gensim.models.keyedvectors.Vocab at 0x7f28263414a8>,
#  'leap': <gensim.models.keyedvectors.Vocab at 0x7f282e43be80>,
#  'fighter': <gensim.models.keyedvectors.Vocab at 0x7f2826341518>,
#  'anti-govern': <gensim.models.keyedvectors.Vocab at 0x7f2826341550>,
#  'octa': <gensim.models.keyedvectors.Vocab at 0x7f2826333358>,
#  'moral': <gensim.models.keyedvectors.Vocab at 0x7f28263415c0>,
#  'queue': <gensim.models.keyedvectors.Vocab at 0x7f282630d1d0>,
#  'gemma': <gensim.models.keyedvectors.Vocab at 0x7f2826341630>,
#  'reanim': <gensim.models.keyedvectors.Vocab at 0x7f2826341668>,
#  'simon': <gensim.models.keyedvectors.Vocab at 0x7f28263416a0>,
#  'mail': <gensim.models.keyedvectors.Vocab at 0x7f28263416d8>,
#  'pervert': <gensim.models.keyedvectors.Vocab at 0x7f2826341748>,
#  'galilei': <gensim.models.keyedvectors.Vocab at 0x7f2826341780>,
#  'swan': <gensim.models.keyedvectors.Vocab at 0x7f28263417f0>,
#  'brydon': <gensim.models.keyedvectors.Vocab at 0x7f2826341828>,
#  'kif': <gensim.models.keyedvectors.Vocab at 0x7f2826341860>,
#  'moko': <gensim.models.keyedvectors.Vocab at 0x7f2826341898>,
#  'box': <gensim.models.keyedvectors.Vocab at 0x7f28263418d0>,
#  'inez': <gensim.models.keyedvectors.Vocab at 0x7f2826238518>,
#  'umbrella': <gensim.models.keyedvectors.Vocab at 0x7f2826341908>,
#  'bicyclist': <gensim.models.keyedvectors.Vocab at 0x7f282e438438>,
#  'bagdad': <gensim.models.keyedvectors.Vocab at 0x7f2826341940>,
#  'market': <gensim.models.keyedvectors.Vocab at 0x7f2826341978>,
#  'distinguish': <gensim.models.keyedvectors.Vocab at 0x7f28263419b0>,
#  'humor': <gensim.models.keyedvectors.Vocab at 0x7f28263419e8>,
#  'upstat': <gensim.models.keyedvectors.Vocab at 0x7f28262eef98>,
#  "'": <gensim.models.keyedvectors.Vocab at 0x7f2826341a58>,
#  'coax': <gensim.models.keyedvectors.Vocab at 0x7f282e444e80>,
#  'tormentor': <gensim.models.keyedvectors.Vocab at 0x7f2826341a90>,
#  'chew': <gensim.models.keyedvectors.Vocab at 0x7f2826341ac8>,
#  'despair': <gensim.models.keyedvectors.Vocab at 0x7f28262564a8>,
#  'vicious': <gensim.models.keyedvectors.Vocab at 0x7f2826341b38>,
#  'crip': <gensim.models.keyedvectors.Vocab at 0x7f2826341b70>,
#  '’': <gensim.models.keyedvectors.Vocab at 0x7f28262385c0>,
#  'coop': <gensim.models.keyedvectors.Vocab at 0x7f2826341be0>,
#  'anni': <gensim.models.keyedvectors.Vocab at 0x7f2826341c18>,
#  '6.': <gensim.models.keyedvectors.Vocab at 0x7f2826335320>,
#  'urgent': <gensim.models.keyedvectors.Vocab at 0x7f2826341c88>,
#  'botanist': <gensim.models.keyedvectors.Vocab at 0x7f2826341cc0>,
#  'abbi': <gensim.models.keyedvectors.Vocab at 0x7f2826341cf8>,
#  'japanese-held': <gensim.models.keyedvectors.Vocab at 0x7f2826341d30>,
#  'crimmin': <gensim.models.keyedvectors.Vocab at 0x7f282e3fc160>,
#  'reserv': <gensim.models.keyedvectors.Vocab at 0x7f2826341da0>,
#  'pessimist': <gensim.models.keyedvectors.Vocab at 0x7f28262be320>,
#  'well-known': <gensim.models.keyedvectors.Vocab at 0x7f2826341e10>,
#  'penelop': <gensim.models.keyedvectors.Vocab at 0x7f282630d3c8>,
#  'rebuilt': <gensim.models.keyedvectors.Vocab at 0x7f2826341e80>,
#  'foreclos': <gensim.models.keyedvectors.Vocab at 0x7f2826341eb8>,
#  'juan': <gensim.models.keyedvectors.Vocab at 0x7f2826341ef0>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x7f2826341f28>,
#  'marston': <gensim.models.keyedvectors.Vocab at 0x7f2826341f60>,
#  'wo': <gensim.models.keyedvectors.Vocab at 0x7f2826341f98>,
#  'conniv': <gensim.models.keyedvectors.Vocab at 0x7f2826341fd0>,
#  'real-lif': <gensim.models.keyedvectors.Vocab at 0x7f2826344048>,
#  'wilverley': <gensim.models.keyedvectors.Vocab at 0x7f2826344080>,
#  'special': <gensim.models.keyedvectors.Vocab at 0x7f28263440b8>,
#  'expuls': <gensim.models.keyedvectors.Vocab at 0x7f28263440f0>,
#  'valis': <gensim.models.keyedvectors.Vocab at 0x7f2826344128>,
#  'sequoia': <gensim.models.keyedvectors.Vocab at 0x7f2826344160>,
#  'sarcophagu': <gensim.models.keyedvectors.Vocab at 0x7f2826344198>,
#  'heatblast': <gensim.models.keyedvectors.Vocab at 0x7f282e3fbfd0>,
#  'vampir': <gensim.models.keyedvectors.Vocab at 0x7f2826344208>,
#  'derid': <gensim.models.keyedvectors.Vocab at 0x7f282e16ee48>,
#  'nona': <gensim.models.keyedvectors.Vocab at 0x7f2826344278>,
#  'perfectli': <gensim.models.keyedvectors.Vocab at 0x7f28263442b0>,
#  'tree': <gensim.models.keyedvectors.Vocab at 0x7f282e405780>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x7f2826344320>,
#  'nobl': <gensim.models.keyedvectors.Vocab at 0x7f2826344358>,
#  'bollywood': <gensim.models.keyedvectors.Vocab at 0x7f28262c3f28>,
#  'springtim': <gensim.models.keyedvectors.Vocab at 0x7f2826344438>,
#  'brice': <gensim.models.keyedvectors.Vocab at 0x7f2826344470>,
#  'cider': <gensim.models.keyedvectors.Vocab at 0x7f28263444e0>,
#  'skagway': <gensim.models.keyedvectors.Vocab at 0x7f2826271a20>,
#  "n't": <gensim.models.keyedvectors.Vocab at 0x7f2826344550>,
#  'wrath': <gensim.models.keyedvectors.Vocab at 0x7f2826344588>,
#  'woodrow': <gensim.models.keyedvectors.Vocab at 0x7f28263445c0>,
#  'barbara': <gensim.models.keyedvectors.Vocab at 0x7f28263445f8>,
#  'dravka': <gensim.models.keyedvectors.Vocab at 0x7f2826344668>,
#  'zeu': <gensim.models.keyedvectors.Vocab at 0x7f282e448898>,
#  'cathi': <gensim.models.keyedvectors.Vocab at 0x7f28263446a0>,
#  'traffick': <gensim.models.keyedvectors.Vocab at 0x7f28263446d8>,
#  'marni': <gensim.models.keyedvectors.Vocab at 0x7f2826344710>,
#  'adelaid': <gensim.models.keyedvectors.Vocab at 0x7f2826344748>,
#  'residenti': <gensim.models.keyedvectors.Vocab at 0x7f2826344780>,
#  'mele': <gensim.models.keyedvectors.Vocab at 0x7f28263447b8>,
#  'former-nazi': <gensim.models.keyedvectors.Vocab at 0x7f28263447f0>,
#  'oglethorp': <gensim.models.keyedvectors.Vocab at 0x7f2826344828>,
#  'spacesuit': <gensim.models.keyedvectors.Vocab at 0x7f2826344898>,
#  'spent': <gensim.models.keyedvectors.Vocab at 0x7f28263448d0>,
#  'shadi': <gensim.models.keyedvectors.Vocab at 0x7f2826344908>,
#  'curti': <gensim.models.keyedvectors.Vocab at 0x7f2826344940>,
#  'disinfect': <gensim.models.keyedvectors.Vocab at 0x7f2826344978>,
#  'hardcastl': <gensim.models.keyedvectors.Vocab at 0x7f28263449b0>,
#  'cleverli': <gensim.models.keyedvectors.Vocab at 0x7f282e44a470>,
#  'vestigi': <gensim.models.keyedvectors.Vocab at 0x7f28263449e8>,
#  'drake': <gensim.models.keyedvectors.Vocab at 0x7f2826344a20>,
#  'insurrectionist': <gensim.models.keyedvectors.Vocab at 0x7f2826344a58>,
#  'now-teenag': <gensim.models.keyedvectors.Vocab at 0x7f2826344a90>,
#  'rupert': <gensim.models.keyedvectors.Vocab at 0x7f2826344ac8>,
#  'grower': <gensim.models.keyedvectors.Vocab at 0x7f2826344b00>,
#  'oven': <gensim.models.keyedvectors.Vocab at 0x7f2826344b38>,
#  'lovestruck': <gensim.models.keyedvectors.Vocab at 0x7f2826344b70>,
#  'counter': <gensim.models.keyedvectors.Vocab at 0x7f2826344ba8>,
#  'stride': <gensim.models.keyedvectors.Vocab at 0x7f28262cd198>,
#  'deputi': <gensim.models.keyedvectors.Vocab at 0x7f2826344c50>,
#  'stellar': <gensim.models.keyedvectors.Vocab at 0x7f28262cd518>,
#  'dolemit': <gensim.models.keyedvectors.Vocab at 0x7f2826344cc0>,
#  'hull': <gensim.models.keyedvectors.Vocab at 0x7f28262cd828>,
#  'withhold': <gensim.models.keyedvectors.Vocab at 0x7f2826344d30>,
#  'reprimand': <gensim.models.keyedvectors.Vocab at 0x7f2826344d68>,
#  'glamor': <gensim.models.keyedvectors.Vocab at 0x7f28262cdb00>,
#  'deter': <gensim.models.keyedvectors.Vocab at 0x7f282e3fc2b0>,
#  'cahoot': <gensim.models.keyedvectors.Vocab at 0x7f28262cdcf8>,
#  'aristocrat': <gensim.models.keyedvectors.Vocab at 0x7f2826344e48>,
#  'evad': <gensim.models.keyedvectors.Vocab at 0x7f2826344e80>,
#  'covington': <gensim.models.keyedvectors.Vocab at 0x7f2826344ef0>,
#  'fathers.wilkin': <gensim.models.keyedvectors.Vocab at 0x7f28262d1358>,
#  'taco': <gensim.models.keyedvectors.Vocab at 0x7f2826344f98>,
#  'involuntarili': <gensim.models.keyedvectors.Vocab at 0x7f2826344fd0>,
#  'ponder': <gensim.models.keyedvectors.Vocab at 0x7f2826347048>,
#  'conceil': <gensim.models.keyedvectors.Vocab at 0x7f2826347080>,
#  'artist': <gensim.models.keyedvectors.Vocab at 0x7f28263470b8>,
#  'q=nbff-day-5-my-run-sicilian-girl': <gensim.models.keyedvectors.Vocab at 0x7f28263470f0>,
#  'greas': <gensim.models.keyedvectors.Vocab at 0x7f2826347128>,
#  'brig': <gensim.models.keyedvectors.Vocab at 0x7f282e3ffa58>,
#  'mind': <gensim.models.keyedvectors.Vocab at 0x7f28262f1438>,
#  'lockhart': <gensim.models.keyedvectors.Vocab at 0x7f28263471d0>,
#  '01-04-2009': <gensim.models.keyedvectors.Vocab at 0x7f282e447dd8>,
#  '--': <gensim.models.keyedvectors.Vocab at 0x7f2826347240>,
#  'murderer—a': <gensim.models.keyedvectors.Vocab at 0x7f2826347278>,
#  'reap': <gensim.models.keyedvectors.Vocab at 0x7f28263472b0>,
#  're-enact': <gensim.models.keyedvectors.Vocab at 0x7f28263472e8>,
# ...
#  'meadow': <gensim.models.keyedvectors.Vocab at 0x7f2826347828>,
#  'ditch': <gensim.models.keyedvectors.Vocab at 0x7f2826347860>,
#  'floyd': <gensim.models.keyedvectors.Vocab at 0x7f2826347898>,
#  'lennon': <gensim.models.keyedvectors.Vocab at 0x7f2826347908>,
#  'hm': <gensim.models.keyedvectors.Vocab at 0x7f2826347978>,
#  'damag': <gensim.models.keyedvectors.Vocab at 0x7f2826256b00>,
#  'grope': <gensim.models.keyedvectors.Vocab at 0x7f28263479e8>,
#  'impression': <gensim.models.keyedvectors.Vocab at 0x7f2826347a20>,
#  'beep': <gensim.models.keyedvectors.Vocab at 0x7f282e44a940>,
#  'peabodi': <gensim.models.keyedvectors.Vocab at 0x7f2826347a90>,
#  'weas': <gensim.models.keyedvectors.Vocab at 0x7f2826347ac8>,
#  'starv': <gensim.models.keyedvectors.Vocab at 0x7f2826347b38>,
#  'virtu': <gensim.models.keyedvectors.Vocab at 0x7f2826347ba8>,
#  'albeit': <gensim.models.keyedvectors.Vocab at 0x7f2826347be0>,
#  'marbl': <gensim.models.keyedvectors.Vocab at 0x7f2826347c18>,
#  'malform': <gensim.models.keyedvectors.Vocab at 0x7f2826347c50>,
#  'rubicon': <gensim.models.keyedvectors.Vocab at 0x7f2826347c88>,
#  'victim': <gensim.models.keyedvectors.Vocab at 0x7f2826347cc0>,
#  'wayn': <gensim.models.keyedvectors.Vocab at 0x7f2826347cf8>,
#  'unwel': <gensim.models.keyedvectors.Vocab at 0x7f2826347d30>,
#  'amina': <gensim.models.keyedvectors.Vocab at 0x7f2826347d68>,
#  'numb': <gensim.models.keyedvectors.Vocab at 0x7f2826347da0>,
#  'alsatia': <gensim.models.keyedvectors.Vocab at 0x7f2826347dd8>,
#  'ed': <gensim.models.keyedvectors.Vocab at 0x7f2826347e10>,
#  'strata': <gensim.models.keyedvectors.Vocab at 0x7f2826347e48>,
#  'instrument': <gensim.models.keyedvectors.Vocab at 0x7f2826347e80>,
#  'storm': <gensim.models.keyedvectors.Vocab at 0x7f2826347eb8>,
#  'vw': <gensim.models.keyedvectors.Vocab at 0x7f2826347ef0>,
#  'unceremoni': <gensim.models.keyedvectors.Vocab at 0x7f28263725c0>,
#  'mega-jerri': <gensim.models.keyedvectors.Vocab at 0x7f2826347f98>,
#  'hellish': <gensim.models.keyedvectors.Vocab at 0x7f2826372a90>,
#  'zenon': <gensim.models.keyedvectors.Vocab at 0x7f2826349048>,
#  'rub': <gensim.models.keyedvectors.Vocab at 0x7f2826349080>,
#  'heat': <gensim.models.keyedvectors.Vocab at 0x7f28263490b8>,
#  'sunris': <gensim.models.keyedvectors.Vocab at 0x7f28263490f0>,
#  'expand': <gensim.models.keyedvectors.Vocab at 0x7f2826349128>,
#  'self-absorb': <gensim.models.keyedvectors.Vocab at 0x7f2826349160>,
#  'scapegoat': <gensim.models.keyedvectors.Vocab at 0x7f2826349198>,
#  'imdb': <gensim.models.keyedvectors.Vocab at 0x7f2826349208>,
#  'tech': <gensim.models.keyedvectors.Vocab at 0x7f2826349240>,
#  'cyclon': <gensim.models.keyedvectors.Vocab at 0x7f282e3fc5f8>,
#  'anu': <gensim.models.keyedvectors.Vocab at 0x7f28263492b0>,
#  'astut': <gensim.models.keyedvectors.Vocab at 0x7f2826238e80>,
#  'celebr': <gensim.models.keyedvectors.Vocab at 0x7f282e407080>,
#  'cameroon': <gensim.models.keyedvectors.Vocab at 0x7f2826349320>,
#  'experienc': <gensim.models.keyedvectors.Vocab at 0x7f2826349358>,
#  'careless': <gensim.models.keyedvectors.Vocab at 0x7f2826349390>,
#  'fruit-sel': <gensim.models.keyedvectors.Vocab at 0x7f28262e7320>,
#  'batter': <gensim.models.keyedvectors.Vocab at 0x7f2826349400>,
#  'roundup': <gensim.models.keyedvectors.Vocab at 0x7f2826349438>,
#  'stowaway': <gensim.models.keyedvectors.Vocab at 0x7f2826349470>,
#  "'real": <gensim.models.keyedvectors.Vocab at 0x7f282e3fc748>,
#  'psychotherapi': <gensim.models.keyedvectors.Vocab at 0x7f28263494e0>,
#  'exert': <gensim.models.keyedvectors.Vocab at 0x7f2826349518>,
#  'briefcas': <gensim.models.keyedvectors.Vocab at 0x7f2826349550>,
#  '3.': <gensim.models.keyedvectors.Vocab at 0x7f2826349588>,
#  'juliet': <gensim.models.keyedvectors.Vocab at 0x7f28263495c0>,
#  'shabbi': <gensim.models.keyedvectors.Vocab at 0x7f28263495f8>,
#  'pa': <gensim.models.keyedvectors.Vocab at 0x7f282630db70>,
#  'rabbi': <gensim.models.keyedvectors.Vocab at 0x7f2826349668>,
#  'siler': <gensim.models.keyedvectors.Vocab at 0x7f28263496a0>,
#  'ron': <gensim.models.keyedvectors.Vocab at 0x7f28263496d8>,
#  'expectantli': <gensim.models.keyedvectors.Vocab at 0x7f2826349710>,
#  'hose': <gensim.models.keyedvectors.Vocab at 0x7f2826349748>,
#  'lever': <gensim.models.keyedvectors.Vocab at 0x7f2826349780>,
#  'jacki': <gensim.models.keyedvectors.Vocab at 0x7f28263497b8>,
#  'durung': <gensim.models.keyedvectors.Vocab at 0x7f28263497f0>,
#  'creditor': <gensim.models.keyedvectors.Vocab at 0x7f2826349828>,
#  'mobil': <gensim.models.keyedvectors.Vocab at 0x7f2826349860>,
#  '100.': <gensim.models.keyedvectors.Vocab at 0x7f2826349898>,
#  'procur': <gensim.models.keyedvectors.Vocab at 0x7f28263498d0>,
#  'danish': <gensim.models.keyedvectors.Vocab at 0x7f2826349908>,
#  'gretel': <gensim.models.keyedvectors.Vocab at 0x7f2826349978>,
#  'dump': <gensim.models.keyedvectors.Vocab at 0x7f28263499b0>,
#  'intend': <gensim.models.keyedvectors.Vocab at 0x7f282e45b7b8>,
#  'aquanaut': <gensim.models.keyedvectors.Vocab at 0x7f28263499e8>,
#  'batgirl': <gensim.models.keyedvectors.Vocab at 0x7f282630dc18>,
#  'lust': <gensim.models.keyedvectors.Vocab at 0x7f2826349a90>,
#  'ratcliff': <gensim.models.keyedvectors.Vocab at 0x7f2826349ac8>,
#  'vaccin': <gensim.models.keyedvectors.Vocab at 0x7f2826349b00>,
#  '|title2008-09-19|work=ni': <gensim.models.keyedvectors.Vocab at 0x7f2826349b38>,
#  'occur': <gensim.models.keyedvectors.Vocab at 0x7f2826349b70>,
#  'vapor': <gensim.models.keyedvectors.Vocab at 0x7f2826349be0>,
#  'artifici': <gensim.models.keyedvectors.Vocab at 0x7f2826349c18>,
#  'dispel': <gensim.models.keyedvectors.Vocab at 0x7f2826256e48>,
#  'steak': <gensim.models.keyedvectors.Vocab at 0x7f2826349c88>,
#  'defer': <gensim.models.keyedvectors.Vocab at 0x7f2826349cc0>,
#  'bamboo': <gensim.models.keyedvectors.Vocab at 0x7f28262f14a8>,
#  'terenc': <gensim.models.keyedvectors.Vocab at 0x7f2826349d30>,
#  'frantic': <gensim.models.keyedvectors.Vocab at 0x7f2826349d68>,
#  'renew': <gensim.models.keyedvectors.Vocab at 0x7f2826349da0>,
#  'airwav': <gensim.models.keyedvectors.Vocab at 0x7f2826349dd8>,
#  'enigma': <gensim.models.keyedvectors.Vocab at 0x7f2826349e10>,
#  'playboy/private-investig': <gensim.models.keyedvectors.Vocab at 0x7f2826349e48>,
#  'durant': <gensim.models.keyedvectors.Vocab at 0x7f2826349e80>,
#  'clearwat': <gensim.models.keyedvectors.Vocab at 0x7f2826349eb8>,
#  'thad': <gensim.models.keyedvectors.Vocab at 0x7f2826349ef0>,
#  'narrowli': <gensim.models.keyedvectors.Vocab at 0x7f2826256ef0>,
#  'carey': <gensim.models.keyedvectors.Vocab at 0x7f2826349f60>,
#  'implement': <gensim.models.keyedvectors.Vocab at 0x7f2826349f98>,
#  'desist': <gensim.models.keyedvectors.Vocab at 0x7f282637d940>,
#  'crabappl': <gensim.models.keyedvectors.Vocab at 0x7f282634c048>,
#  'barren': <gensim.models.keyedvectors.Vocab at 0x7f282634c080>,
#  'jack—anoth': <gensim.models.keyedvectors.Vocab at 0x7f282634c0b8>,
#  'williamsburg': <gensim.models.keyedvectors.Vocab at 0x7f282634c0f0>,
#  'astronaut': <gensim.models.keyedvectors.Vocab at 0x7f282634c128>,
#  'wanda': <gensim.models.keyedvectors.Vocab at 0x7f282634c160>,
#  'nanni': <gensim.models.keyedvectors.Vocab at 0x7f282634c198>,
#  'inquir': <gensim.models.keyedvectors.Vocab at 0x7f282634c1d0>,
#  'duo': <gensim.models.keyedvectors.Vocab at 0x7f282634c208>,
#  'guis': <gensim.models.keyedvectors.Vocab at 0x7f282634c240>,
#  'self-portrait': <gensim.models.keyedvectors.Vocab at 0x7f282634c278>,
#  'judgement': <gensim.models.keyedvectors.Vocab at 0x7f28262f1978>,
#  'engulf': <gensim.models.keyedvectors.Vocab at 0x7f282634c2e8>,
#  'kidnap': <gensim.models.keyedvectors.Vocab at 0x7f2826259048>,
#  'ill-kempt': <gensim.models.keyedvectors.Vocab at 0x7f282634c358>,
#  'split': <gensim.models.keyedvectors.Vocab at 0x7f282634c390>,
#  'anger': <gensim.models.keyedvectors.Vocab at 0x7f282634c3c8>,
#  'ensur': <gensim.models.keyedvectors.Vocab at 0x7f282634c400>,
#  'morphin': <gensim.models.keyedvectors.Vocab at 0x7f282634c438>,
#  'cross-bord': <gensim.models.keyedvectors.Vocab at 0x7f282634c470>,
#  'westi': <gensim.models.keyedvectors.Vocab at 0x7f282634c4e0>,
#  'pickett': <gensim.models.keyedvectors.Vocab at 0x7f28262f19e8>,
#  'unsur': <gensim.models.keyedvectors.Vocab at 0x7f282634c550>,
#  '1996.': <gensim.models.keyedvectors.Vocab at 0x7f282634c588>,
#  'anglo-italian': <gensim.models.keyedvectors.Vocab at 0x7f282634c5c0>,
#  'picton': <gensim.models.keyedvectors.Vocab at 0x7f282e3fca58>,
#  'ndash': <gensim.models.keyedvectors.Vocab at 0x7f282634c630>,
#  'yuri': <gensim.models.keyedvectors.Vocab at 0x7f282634c668>,
#  '104': <gensim.models.keyedvectors.Vocab at 0x7f282634c6a0>,
#  'needi': <gensim.models.keyedvectors.Vocab at 0x7f282e4399b0>,
#  'cukrowicz': <gensim.models.keyedvectors.Vocab at 0x7f282634c710>,
#  '1933': <gensim.models.keyedvectors.Vocab at 0x7f282634c748>,
#  'livestock': <gensim.models.keyedvectors.Vocab at 0x7f28261bf240>,
#  'stabilis': <gensim.models.keyedvectors.Vocab at 0x7f282634c7f0>,
#  'limousin': <gensim.models.keyedvectors.Vocab at 0x7f282634c828>,
#  'packag': <gensim.models.keyedvectors.Vocab at 0x7f282634c860>,
#  'mask': <gensim.models.keyedvectors.Vocab at 0x7f282634c8d0>,
#  'purvianc': <gensim.models.keyedvectors.Vocab at 0x7f282634c908>,
#  'sieg': <gensim.models.keyedvectors.Vocab at 0x7f282627f710>,
#  'dwell': <gensim.models.keyedvectors.Vocab at 0x7f282634c978>,
#  'commission': <gensim.models.keyedvectors.Vocab at 0x7f282634c9b0>,
#  'lamb': <gensim.models.keyedvectors.Vocab at 0x7f282634c9e8>,
#  'chickasaw': <gensim.models.keyedvectors.Vocab at 0x7f282634ca20>,
#  '20th': <gensim.models.keyedvectors.Vocab at 0x7f282634ca58>,
#  'exhibitionist': <gensim.models.keyedvectors.Vocab at 0x7f282e069908>,
#  'feminin': <gensim.models.keyedvectors.Vocab at 0x7f282634ca90>,
#  'flappi': <gensim.models.keyedvectors.Vocab at 0x7f282634cb00>,
#  'tradition—ar': <gensim.models.keyedvectors.Vocab at 0x7f282634cb38>,
#  'came': <gensim.models.keyedvectors.Vocab at 0x7f282e404550>,
#  'shopgirl': <gensim.models.keyedvectors.Vocab at 0x7f28262cb630>,
#  'agit': <gensim.models.keyedvectors.Vocab at 0x7f282634cba8>,
#  'worst': <gensim.models.keyedvectors.Vocab at 0x7f282634cbe0>,
#  'videograph': <gensim.models.keyedvectors.Vocab at 0x7f282634cc18>,
#  'situat': <gensim.models.keyedvectors.Vocab at 0x7f282634cc50>,
#  'signatur': <gensim.models.keyedvectors.Vocab at 0x7f282e454e80>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x7f282634cc88>,
#  '1963': <gensim.models.keyedvectors.Vocab at 0x7f282e44def0>,
#  'garner': <gensim.models.keyedvectors.Vocab at 0x7f282634ccf8>,
#  'vitamin': <gensim.models.keyedvectors.Vocab at 0x7f282634cd30>,
#  '1952': <gensim.models.keyedvectors.Vocab at 0x7f282634cd68>,
#  'mack': <gensim.models.keyedvectors.Vocab at 0x7f282634cda0>,
#  'premis': <gensim.models.keyedvectors.Vocab at 0x7f282e44a898>,
#  'weird': <gensim.models.keyedvectors.Vocab at 0x7f282634cdd8>,
#  'embed': <gensim.models.keyedvectors.Vocab at 0x7f282634ce10>,
#  'rumspringa': <gensim.models.keyedvectors.Vocab at 0x7f282634ce48>,
#  'finalist': <gensim.models.keyedvectors.Vocab at 0x7f282634ce80>,
#  'mess': <gensim.models.keyedvectors.Vocab at 0x7f282634ceb8>,
#  'alan': <gensim.models.keyedvectors.Vocab at 0x7f282634cef0>,
#  'motorcycl': <gensim.models.keyedvectors.Vocab at 0x7f282634cf28>,
#  'chattanooga': <gensim.models.keyedvectors.Vocab at 0x7f282634cf60>,
#  'plop': <gensim.models.keyedvectors.Vocab at 0x7f282634cf98>,
#  'respect': <gensim.models.keyedvectors.Vocab at 0x7f282634cfd0>,
#  'gorg': <gensim.models.keyedvectors.Vocab at 0x7f282634f048>,
#  'sorrow': <gensim.models.keyedvectors.Vocab at 0x7f282634f080>,
#  'pencil': <gensim.models.keyedvectors.Vocab at 0x7f282623a5c0>,
#  'user': <gensim.models.keyedvectors.Vocab at 0x7f282634f0f0>,
#  'crowd': <gensim.models.keyedvectors.Vocab at 0x7f282634f128>,
#  'veronica': <gensim.models.keyedvectors.Vocab at 0x7f282634f160>,
#  'introduc': <gensim.models.keyedvectors.Vocab at 0x7f282e444a58>,
#  'flamboy': <gensim.models.keyedvectors.Vocab at 0x7f282634f1d0>,
#  'dnr': <gensim.models.keyedvectors.Vocab at 0x7f282634f208>,
#  'murray': <gensim.models.keyedvectors.Vocab at 0x7f282634f240>,
#  'organis': <gensim.models.keyedvectors.Vocab at 0x7f282634f278>,
#  'affluent': <gensim.models.keyedvectors.Vocab at 0x7f282e444470>,
#  'dissatisfi': <gensim.models.keyedvectors.Vocab at 0x7f282634f2e8>,
#  'nigel': <gensim.models.keyedvectors.Vocab at 0x7f282634f320>,
#  'accordingli': <gensim.models.keyedvectors.Vocab at 0x7f282634f390>,
#  'lioniz': <gensim.models.keyedvectors.Vocab at 0x7f282e3fdb70>,
#  'transcend': <gensim.models.keyedvectors.Vocab at 0x7f282634f3c8>,
#  'withdrew': <gensim.models.keyedvectors.Vocab at 0x7f282634f400>,
#  'vessel': <gensim.models.keyedvectors.Vocab at 0x7f282634f438>,
#  'smoke': <gensim.models.keyedvectors.Vocab at 0x7f282634f470>,
#  '20-year': <gensim.models.keyedvectors.Vocab at 0x7f282634f4a8>,
#  'obsolet': <gensim.models.keyedvectors.Vocab at 0x7f282634f4e0>,
#  'fanat': <gensim.models.keyedvectors.Vocab at 0x7f282634f518>,
#  'itinerari': <gensim.models.keyedvectors.Vocab at 0x7f282634f550>,
#  'hunger': <gensim.models.keyedvectors.Vocab at 0x7f282634f588>,
#  'syndic': <gensim.models.keyedvectors.Vocab at 0x7f282634f5c0>,
#  'buzz': <gensim.models.keyedvectors.Vocab at 0x7f282634f5f8>,
#  'quirki': <gensim.models.keyedvectors.Vocab at 0x7f282634f668>,
#  'career-mind': <gensim.models.keyedvectors.Vocab at 0x7f282634f6a0>,
#  'purl': <gensim.models.keyedvectors.Vocab at 0x7f282634f6d8>,
#  'fifer': <gensim.models.keyedvectors.Vocab at 0x7f282634f710>,
#  'backup': <gensim.models.keyedvectors.Vocab at 0x7f282634f748>,
#  'dri': <gensim.models.keyedvectors.Vocab at 0x7f2826281d68>,
#  'soleil': <gensim.models.keyedvectors.Vocab at 0x7f282634f780>,
#  'tyrann': <gensim.models.keyedvectors.Vocab at 0x7f282c1bb588>,
#  'gadgetri': <gensim.models.keyedvectors.Vocab at 0x7f282634f7b8>,
#  'six-month': <gensim.models.keyedvectors.Vocab at 0x7f282634f7f0>,
#  'unnecessari': <gensim.models.keyedvectors.Vocab at 0x7f2826278940>,
#  'remnant': <gensim.models.keyedvectors.Vocab at 0x7f282639f780>,
#  'baptism': <gensim.models.keyedvectors.Vocab at 0x7f282634f898>,
#  'reach': <gensim.models.keyedvectors.Vocab at 0x7f282634f8d0>,
#  'miniatur': <gensim.models.keyedvectors.Vocab at 0x7f282634f908>,
#  'elmira': <gensim.models.keyedvectors.Vocab at 0x7f282634f940>,
#  'self-hatr': <gensim.models.keyedvectors.Vocab at 0x7f282634f978>,
#  'thunderclap': <gensim.models.keyedvectors.Vocab at 0x7f282634f9b0>,
#  'johann': <gensim.models.keyedvectors.Vocab at 0x7f282634f9e8>,
#  'old-fashion': <gensim.models.keyedvectors.Vocab at 0x7f282634fa20>,
#  'cod': <gensim.models.keyedvectors.Vocab at 0x7f282634fa58>,
#  'minefield': <gensim.models.keyedvectors.Vocab at 0x7f282e444710>,
#  'ophelia': <gensim.models.keyedvectors.Vocab at 0x7f28261c8ac8>,
#  'sickb': <gensim.models.keyedvectors.Vocab at 0x7f282e461a20>,
#   3.9449234e-02 -1.5926700e-02  2.0334179e-02 -4.6289943e-02
#  -6.3441366e-02 -1.0615947e-02 -3.3121288e-02 -1.2643595e-01
#  -1.1214208e-02 -1.7272104e-02  2.3765728e-02  4.1994680e-02
#   6.8464771e-02  3.9380208e-02  9.7083308e-02 -5.0399635e-02
#   2.1558857e-02  6.7361319e-03  7.0044847e-04  1.5541139e-01]
# /home/ubuntu/MovieGenrePrediction/env/lib/python3.5/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-12bb62edb38d> in <module>()
# ----> 1 words = tokenize(x)
#       2 print(words)
#
# <ipython-input-8-81e0b1197311> in tokenize(text)
#       1 def tokenize(text):
# ----> 2     text = text.lower()
#       3     tokens = nltk.word_tokenize(text)
#       4     filtered = [word for word in tokens if word not in stop_words]
#       5     stems = stem_tokens(filtered, stemmer)
#
# ~/MovieGenrePrediction/env/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
word_bag = np.empty(len(x), dtype = object)

i = 0;
for item in x: 
    word_bag[i] = list(set(tokenize(item)))
    i = i+1

word_bag = list(word_bag)
for index,item in np.ndenumerate(word_bag):
    val = word_model[item]
    word_bag[index[0]] = val
    
print(word_bag[0])
# Out:
# /home/ubuntu/MovieGenrePrediction/env/lib/python3.5/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # This is added back by InteractiveShellApp.init_path()
# [[ 0.68966603 -0.11382978 -1.0269581  ...  0.74553204  0.0284878
#   -0.06229448]
#  [ 0.0657037  -0.00742911 -0.1097706  ...  0.07979269  0.00847356
#    0.00478697]
#  [ 0.70029944 -0.13451599 -1.1198015  ...  0.8492055   0.01483014
#   -0.003225  ]
#  ...
#  [ 0.23740603 -0.04244184 -0.40878245 ...  0.30529428  0.01458694
#    0.0142892 ]
#  [ 0.48926884 -0.07848854 -0.84620744 ...  0.62439615  0.04812754
#    0.01820501]
#  [ 0.56107336 -0.11164133 -0.8804169  ...  0.66044694  0.00829607
#   -0.01529546]]

# %%
def build_model():
    classifier = MLPClassifier((14,))
    
    x_train, x_test, y_train, y_test = train_test_split(word_bag, y, test_size=0.3)

    model = classifier.fit(x_train, y_train)
    predictions = model.predict(x_test)
    target_names = dataset.drop(["summary"], axis=1).columns.tolist()
    score = jaccard_similarity_score(y_test, predictions)
    print(score)
    return classification_report(y_test, predictions, target_names= target_names)

# %%
results = build_model()
print(results)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-1c07877ec49c> in <module>()
# ----> 1 results = build_model()
#       2 print(results)
#
# <ipython-input-55-f39bd3e7b7a3> in build_model()
#       4     x_train, x_test, y_train, y_test = train_test_split(word_bag, y, test_size=0.3)
#       5
# ----> 6     model = classifier.fit(x_train, y_train)
#       7     predictions = model.predict(x_test)
#       8     target_names = dataset.drop(["summary"], axis=1).columns.tolist()
#
# ~/MovieGenrePrediction/env/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py in fit(self, X, y)
#     971         """
#     972         return self._fit(X, y, incremental=(self.warm_start and
# --> 973                                             hasattr(self, "classes_")))
#     974
#     975     @property
#
# ~/MovieGenrePrediction/env/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py in _fit(self, X, y, incremental)
#     329                              hidden_layer_sizes)
#     330
# --> 331         X, y = self._validate_input(X, y, incremental)
#     332         n_samples, n_features = X.shape
#     333
#
# ~/MovieGenrePrediction/env/lib/python3.5/site-packages/sklearn/neural_network/multilayer_perceptron.py in _validate_input(self, X, y, incremental)
#     908     def _validate_input(self, X, y, incremental):
#     909         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 910                          multi_output=True)
#     911         if y.ndim == 2 and y.shape[1] == 1:
#     912             y = column_or_1d(y, warn=True)
#
# ~/MovieGenrePrediction/env/lib/python3.5/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
#     572                     ensure_2d, allow_nd, ensure_min_samples,
# --> 573                     ensure_min_features, warn_on_dtype, estimator)
#     574     if multi_output:
#     575         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~/MovieGenrePrediction/env/lib/python3.5/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     439                     "Reshape your data either using array.reshape(-1, 1) if "
#     440                     "your data has a single feature or array.reshape(1, -1) "
# --> 441                     "if it contains a single sample.".format(array))
#     442             array = np.atleast_2d(array)
#     443             # To ensure that array flags are maintained
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[array([[ 3.08869518e-02, -6.27935305e-03, -5.31315506e-02, ...,
#          3.74948196e-02,  1.63214386e-03,  3.20720416e-03],
#        [ 2.77288016e-02, -9.13671870e-03, -4.33591567e-02, ...,
#          3.67177688e-02, -8.18882487e-04,  6.89205946e-04],
#        [ 3.46365392e-01, -6.70145825e-02, -5.86809993e-01, ...,
#          4.26933110e-01,  2.36974731e-02,  5.65078994e-03],
#        ...,
#        [ 2.65820801e-01, -5.25242649e-02, -4.50395912e-01, ...,
#          3.29225987e-01,  1.33004151e-02,  1.02011198e-02],
#        [ 4.46026504e-01, -8.45604986e-02, -7.23016083e-01, ...,
#          5.43453217e-01,  1.85802300e-02, -8.19864590e-03],
#        [ 8.19389671e-02, -1.27015440e-02, -1.48736730e-01, ...,
#          1.08274005e-01,  4.68267873e-03,  4.66206204e-03]], dtype=float32)
#  array([[ 0.1783008 , -0.03195903, -0.28803006, ...,  0.21418838,
#          0.001529  ,  0.00263789],
#        [ 0.16997936, -0.03564261, -0.27809015, ...,  0.20827085,
#          0.00129848, -0.00217373],
#        [ 0.16771051, -0.03102264, -0.28243145, ...,  0.19783276,
#          0.01979102,  0.00740961],
#        ...,
#        [ 0.63191396, -0.10209434, -0.9322493 , ...,  0.67396265,
#          0.04130398, -0.07123957],
#        [ 0.00531447,  0.00327861, -0.00993951, ...,  0.01288754,
#         -0.00116728, -0.0013503 ],
#        [ 0.24001785, -0.0387562 , -0.3776199 , ...,  0.28191587,
#          0.00777734, -0.00217593]], dtype=float32)
#  array([[ 0.18104546, -0.0319221 , -0.30533788, ...,  0.23209009,
#          0.010616  ,  0.01312464],
#        [ 0.2581069 , -0.04923139, -0.4397059 , ...,  0.32687762,
#          0.00587788,  0.01206225],
#        [ 0.17299095, -0.03850583, -0.29184192, ...,  0.22084661,
#          0.01018118,  0.0061447 ],
#        ...,
#        [ 0.10118119, -0.01702147, -0.1734254 , ...,  0.12728396,
#          0.01010266,  0.00273227],
#        [ 0.56107336, -0.11164133, -0.8804169 , ...,  0.66044694,
#          0.00829607, -0.01529546],
#        [ 0.19073234, -0.03851147, -0.31971923, ...,  0.23664242,
#          0.00571457,  0.00445418]], dtype=float32)
#  array([[ 0.6411545 , -0.11145582, -1.0084254 , ...,  0.76373845,
#          0.04335325, -0.02152833],
#        [ 0.12375046, -0.02663223, -0.2048684 , ...,  0.15250494,
#          0.0107321 , -0.0029751 ],
#        [ 0.01310949, -0.00420965, -0.02005195, ...,  0.00973031,
#          0.00416416, -0.00417639],
#        ...,
#        [ 0.00999408, -0.00698708, -0.02487986, ...,  0.02101636,
#          0.00476143, -0.00105769],
#        [ 0.22260202, -0.03986446, -0.39330766, ...,  0.28276715,
#          0.0087084 ,  0.01064845],
#        [ 0.8067313 , -0.14367762, -0.94424504, ...,  0.7154599 ,
#          0.0184148 , -0.14062928]], dtype=float32)
#  array([[ 0.6609321 , -0.12797694, -1.0951084 , ...,  0.82943434,
#          0.01840308,  0.02186589],
#        [ 0.62061006, -0.12465868, -1.0604745 , ...,  0.7785537 ,
#          0.03655583,  0.01220794],
#        [ 0.5361722 , -0.11133293, -0.95155716, ...,  0.69039196,
#          0.03993915,  0.01023448],
#        ...,
#        [ 0.55280465, -0.10448655, -0.8756484 , ...,  0.63514495,
#          0.03857682, -0.02493809],
#        [ 0.55569893, -0.09952559, -0.89871025, ...,  0.66804343,
#          0.02266019, -0.0066695 ],
#        [ 0.40382814, -0.07732171, -0.6799239 , ...,  0.5076936 ,
#          0.02060179,  0.00135988]], dtype=float32)
#  array([[ 0.40681258, -0.08128243, -0.6895152 , ...,  0.5126732 ,
#          0.01961879,  0.01217256],
#        [ 0.6411545 , -0.11145582, -1.0084254 , ...,  0.76373845,
#          0.04335325, -0.02152833],
#        [ 0.41074246, -0.07937248, -0.6586139 , ...,  0.49525353,
#          0.01212853,  0.00137358],
#        ...,
#        [ 0.47165415, -0.09249631, -0.7438925 , ...,  0.5593399 ,
#          0.0115817 , -0.00414275],
#        [ 0.8067313 , -0.14367762, -0.94424504, ...,  0.7154599 ,
#          0.0184148 , -0.14062928],
#        [ 0.6920409 , -0.12213937, -0.9508452 , ...,  0.6915739 ,
#          0.02761169, -0.10711171]], dtype=float32)
#  array([[ 0.5173662 , -0.094224  , -0.77966696, ...,  0.58314896,
#          0.00614284, -0.02427231],
#        [ 0.6343865 , -0.11976792, -0.94298124, ...,  0.7022181 ,
#          0.01484382, -0.03714199],
#        [ 0.35748142, -0.06924076, -0.59420705, ...,  0.43547967,
#          0.03352366, -0.01309152],
#        ...,
#        [ 0.5962214 , -0.11295866, -0.9510657 , ...,  0.7398903 ,
#          0.00239146,  0.00376792],
#        [ 0.01899357, -0.00859421, -0.0306929 , ...,  0.02634681,
#          0.00367337, -0.00402095],
#        [ 0.49789566, -0.09443165, -0.7937232 , ...,  0.6182698 ,
#          0.00109857,  0.01282176]], dtype=float32)
#  array([[ 0.5173662 , -0.094224  , -0.77966696, ...,  0.58314896,
#          0.00614284, -0.02427231],
#        [ 0.3952677 , -0.06664595, -0.6699945 , ...,  0.5054251 ,
#          0.0215031 ,  0.0179093 ],
#        [ 0.07358148, -0.01412535, -0.1239676 , ...,  0.08759651,
#          0.00578671,  0.00144933],
#        ...,
#        [ 0.6815649 , -0.12429286, -1.0327696 , ...,  0.78177613,
#          0.01586573, -0.03738726],
#        [ 0.14470609, -0.03204703, -0.26257905, ...,  0.193249  ,
#          0.01425591,  0.00837734],
#        [ 0.36640316, -0.06652988, -0.62211734, ...,  0.450364  ,
#          0.02251724,  0.00441404]], dtype=float32)
#  array([[ 1.5929988e-01, -2.7530231e-02, -2.8594249e-01, ...,
#          2.1185035e-01,  1.2288283e-02,  8.3818501e-03],
#        [ 1.5221116e-01, -2.8202942e-02, -2.8067559e-01, ...,
#          2.0352030e-01,  1.1062892e-02,  4.8596356e-03],
#        [ 4.5684665e-01, -8.2845986e-02, -7.7658069e-01, ...,
#        [ 0.07654914, -0.01784079, -0.14607494, ...,  0.10999729,
#          0.01504259,  0.00151266],
#        [ 0.09112356, -0.0153564 , -0.14275786, ...,  0.0992172 ,
#          0.00732651,  0.0032637 ],
#        ...,
#        [ 0.40509936, -0.07308607, -0.66014296, ...,  0.48946425,
#          0.02424051,  0.00312207],
#        [ 0.2631063 , -0.05380339, -0.42972717, ...,  0.3205104 ,
#          0.01592878, -0.00260024],
#        [ 0.03822631, -0.01081117, -0.06048498, ...,  0.04055974,
#          0.00189459, -0.00222373]], dtype=float32)
#  array([[ 0.2237224 , -0.03468407, -0.3961007 , ...,  0.2835035 ,
#          0.01926391,  0.01888034],
#        [ 0.5744133 , -0.1206407 , -0.9265599 , ...,  0.68709385,
#          0.02203717, -0.02822975],
#        [ 0.6763299 , -0.1250392 , -1.0158067 , ...,  0.75609875,
#          0.01116109, -0.03183101],
#        ...,
#        [ 0.43637398, -0.08289664, -0.74905837, ...,  0.5578558 ,
#          0.02166082,  0.01136943],
#        [ 0.05648188, -0.0063145 , -0.09322171, ...,  0.07102437,
#          0.00361006, -0.00572983],
#        [ 0.3008429 , -0.05527252, -0.4824378 , ...,  0.36259845,
#          0.01017251,  0.00487785]], dtype=float32)
#  array([[ 0.18051656, -0.03464852, -0.31477606, ...,  0.23717809,
#          0.01034865,  0.00108479],
#        [ 0.3337865 , -0.06246391, -0.55269593, ...,  0.41074982,
#          0.01876295,  0.00358401],
#        [ 0.2441146 , -0.05218458, -0.4218868 , ...,  0.31400365,
#          0.01281564,  0.00899173],
#        ...,
#        [ 0.11109249, -0.02480933, -0.19463071, ...,  0.14480671,
#          0.00256322,  0.0051675 ],
#        [ 0.06315433, -0.01703225, -0.10299951, ...,  0.08035325,
#         -0.00211691, -0.00334399],
#        [ 0.24308544, -0.04901401, -0.40065062, ...,  0.29067272,
#          0.01368301,  0.0068691 ]], dtype=float32)
#  array([[ 0.06850057, -0.00838315, -0.11757173, ...,  0.09209795,
#         -0.00146961,  0.00281928],
#        [ 0.01878035, -0.00212528, -0.02706832, ...,  0.02233622,
#          0.00493335,  0.00180581],
#        [ 0.68966603, -0.11382978, -1.0269581 , ...,  0.74553204,
#          0.0284878 , -0.06229448],
#        ...,
#        [ 0.2877257 , -0.05768973, -0.48812988, ...,  0.36066067,
#          0.01050441,  0.01158909],
#        [ 0.19073234, -0.03851147, -0.31971923, ...,  0.23664242,
#          0.00571457,  0.00445418],
#        [ 0.28128433, -0.05261739, -0.47049564, ...,  0.34761786,
#          0.01304964,  0.00689176]], dtype=float32)
#  array([[ 0.44900432, -0.08495066, -0.7481627 , ...,  0.5615387 ,
#          0.01452702,  0.01472846],
#        [ 0.7516801 , -0.12256238, -1.0587721 , ...,  0.7800866 ,
#          0.05215018, -0.07100074],
#        [ 0.10142682, -0.02316476, -0.16713788, ...,  0.12306268,
#          0.00113924,  0.00169927],
#        ...,
#        [ 0.03223681, -0.00245238, -0.04798957, ...,  0.03999311,
#         -0.00170118, -0.00398053],
#        [ 0.02524106, -0.00313738, -0.03940786, ...,  0.03382908,
#          0.00684852, -0.00407428],
#        [ 0.48926884, -0.07848854, -0.84620744, ...,  0.62439615,
#          0.04812754,  0.01820501],
#        [ 0.02560109, -0.00623219, -0.03651768, ...,  0.03472104,
#          0.00245755,  0.00151553],
#        [ 0.20377658, -0.03633182, -0.34500238, ...,  0.25431544,
#          0.00703963,  0.01306784]], dtype=float32)
#  array([[ 0.4783065 , -0.08918867, -0.75432336, ...,  0.5604034 ,
#          0.0223714 , -0.01071368],
#        [ 0.23325257, -0.04196937, -0.41452575, ...,  0.3063141 ,
#          0.01971819,  0.00460831],
#        [ 0.09412076, -0.02126445, -0.1580187 , ...,  0.11577749,
#          0.00320019, -0.00189514],
#        ...,
#        [ 0.2631063 , -0.05380339, -0.42972717, ...,  0.3205104 ,
#          0.01592878, -0.00260024],
#        [ 0.7720352 , -0.1409573 , -0.95648897, ...,  0.728646  ,
#          0.00616093, -0.15335192],
#        [ 0.6920409 , -0.12213937, -0.9508452 , ...,  0.6915739 ,
#          0.02761169, -0.10711171]], dtype=float32)
#  array([[ 0.17299095, -0.03850583, -0.29184192, ...,  0.22084661,
#          0.01018118,  0.0061447 ],
#        [ 0.45684665, -0.08284599, -0.7765807 , ...,  0.561376  ,
#          0.02895444,  0.00786149],
#        [ 0.5204739 , -0.10059945, -0.9304071 , ...,  0.6819525 ,
#          0.03706289,  0.03155792],
#        ...,
#        [ 0.03508973, -0.00890658, -0.07253064, ...,  0.04938684,
#          0.00675373,  0.00824716],
#        [ 0.18607077, -0.03590849, -0.31421643, ...,  0.22592829,
#          0.00895831,  0.00680038],
#        [ 0.5962214 , -0.11295866, -0.9510657 , ...,  0.7398903 ,
#          0.00239146,  0.00376792]], dtype=float32)
#  array([[ 3.5914920e-02, -6.5659769e-03, -5.9241772e-02, ...,
#          4.5519110e-02,  1.1081564e-05,  3.4081065e-03],
#        [ 1.9190313e-01, -3.1656090e-02, -3.1582355e-01, ...,
#          2.2518800e-01,  1.9611994e-02, -2.1920451e-03],
#        [ 7.3311186e-01, -1.3326104e-01, -1.0798547e+00, ...,
#          7.8544158e-01,  5.1015325e-02, -6.6577293e-02],
#        ...,
#        [ 6.8156493e-01, -1.2429286e-01, -1.0327696e+00, ...,
#          7.8177613e-01,  1.5865734e-02, -3.7387259e-02],
#        [ 8.4523149e-02, -1.1734164e-02, -1.4388803e-01, ...,
#          1.0443210e-01,  1.0160520e-02, -4.4694515e-03],
#        [ 3.5172325e-01, -6.5850653e-02, -6.1667150e-01, ...,
#          4.5654216e-01,  1.9600939e-02,  2.7137566e-02]], dtype=float32)
#  array([[ 7.50557855e-02, -1.33391023e-02, -1.20798483e-01, ...,
#          8.65562409e-02,  4.44861781e-03,  1.50482508e-03],
#        [ 8.53033736e-03,  2.84315227e-03, -7.67912623e-03, ...,
#          3.07694217e-03, -9.65394865e-05,  3.64391436e-03],
#        [ 5.60405292e-02, -1.07904952e-02, -8.42860639e-02, ...,
#          5.85135520e-02,  3.09322029e-03, -2.79895449e-03],
#        ...,
#        [ 4.35293078e-01, -8.82627591e-02, -7.33422399e-01, ...,
#          5.43347001e-01,  1.51069723e-02,  1.71675123e-02],
#        [ 5.01461513e-03,  3.43647180e-03, -6.93559647e-03, ...,
#          4.86987038e-03,  7.56461464e-04, -3.32411355e-03],
#        [ 1.62800327e-01, -3.44788358e-02, -2.64538586e-01, ...,
#          1.95030034e-01,  3.65166529e-03, -6.15352718e-03],
#        ...,
#        [ 2.34722838e-01, -4.78005558e-02, -4.21249956e-01, ...,
#          3.01969022e-01,  1.96121112e-02,  1.37005486e-02],
#        [ 1.97098732e-01, -3.42370048e-02, -3.45279247e-01, ...,
#          2.58721173e-01,  8.32797866e-03,  8.58934887e-04],
#        [ 5.61073363e-01, -1.11641325e-01, -8.80416930e-01, ...,
#          6.60446942e-01,  8.29606503e-03, -1.52954636e-02]], dtype=float32)
#  array([[ 0.3952677 , -0.06664595, -0.6699945 , ...,  0.5054251 ,
#          0.0215031 ,  0.0179093 ],
#        [ 0.40148544, -0.07701886, -0.6328307 , ...,  0.47719416,
#          0.00995466, -0.0010312 ],
#        [ 0.22724782, -0.04761209, -0.41175172, ...,  0.30240655,
#          0.01330244,  0.01413103],
#        ...,
#        [ 0.07572352, -0.01251529, -0.12468946, ...,  0.08827914,
#          0.00494841,  0.00503317],
#        [ 0.56107336, -0.11164133, -0.8804169 , ...,  0.66044694,
#          0.00829607, -0.01529546],
#        [ 0.24193056, -0.04269446, -0.3733335 , ...,  0.2803908 ,
#          0.00691838, -0.0132022 ]], dtype=float32)
#  array([[ 0.04376797, -0.00853356, -0.08115362, ...,  0.05802327,
#          0.00249784,  0.00106173],
#        [ 0.21786907, -0.04237333, -0.35435453, ...,  0.25813544,
#          0.02047516, -0.0020909 ],
#        [ 0.39886677, -0.07407849, -0.64625055, ...,  0.47096393,
#          0.01671718, -0.00419471],
#        ...,
#        [ 0.05566266, -0.00667974, -0.08661244, ...,  0.07169827,
#          0.00615082,  0.00312287],
#        [ 0.567409  , -0.11433925, -0.9300781 , ...,  0.705177  ,
#          0.01449362,  0.01271733],
#        [ 0.56107336, -0.11164133, -0.8804169 , ...,  0.66044694,
#          0.00829607, -0.01529546]], dtype=float32)
#  array([[ 0.6411545 , -0.11145582, -1.0084254 , ...,  0.76373845,
#          0.04335325, -0.02152833],
#        [ 0.27133757, -0.05247236, -0.45918128, ...,  0.34014902,
#          0.01565154,  0.00710614],
#        [ 0.7516801 , -0.12256238, -1.0587721 , ...,  0.7800866 ,
#          0.05215018, -0.07100074],
#        ...,
#        [ 0.6471284 , -0.14212729, -1.0264348 , ...,  0.80870366,
#         -0.03414745,  0.03964431],
#        [ 0.67186147, -0.12996183, -1.0746675 , ...,  0.8029338 ,
#          0.05694114, -0.05950863],
#        [ 0.17892396, -0.0298714 , -0.32526842, ...,  0.23918045,
#          0.01991338,  0.00745361]], dtype=float32)
#  array([[ 5.4648936e-01, -1.0554771e-01, -8.7299424e-01, ...,
#          6.5758073e-01,  1.1785234e-02, -2.4357140e-04],
#        [ 2.2456135e-01, -3.6044702e-02, -3.9883777e-01, ...,
#          2.8911701e-01,  2.0471949e-02,  7.3939427e-03],
#        [ 6.2450594e-01, -1.1528648e-01, -1.0436925e+00, ...,
#          7.8112900e-01,  1.6371772e-02,  1.5803594e-02],
#        ...,
#        [ 3.3727208e-01, -6.8365045e-02, -5.7567865e-01, ...,
#          4.3576658e-01,  1.3656353e-02,  1.4199782e-02],
#        [ 3.9053354e-01, -6.9446936e-02, -6.3945222e-01, ...,
#          4.7765517e-01,  2.0694785e-02,  4.6976702e-03],
#        [ 4.2827558e-03, -2.9387397e-03, -1.8022953e-02, ...,
#          7.7854213e-03, -2.9524483e-03, -3.7019348e-03]], dtype=float32)
#  array([[ 0.18104546, -0.0319221 , -0.30533788, ...,  0.23209009,
#          0.010616  ,  0.01312464],
#        [ 0.6609321 , -0.12797694, -1.0951084 , ...,  0.82943434,
#          0.01840308,  0.02186589],
#        [ 0.2441146 , -0.05218458, -0.4218868 , ...,  0.31400365,
#          0.01281564,  0.00899173],
#        ...,
#        [ 0.40992424, -0.08024923, -0.67741627, ...,  0.49305758,
#          0.02355338,  0.00506803],
#        [ 0.67186147, -0.12996183, -1.0746675 , ...,  0.8029338 ,
#          0.05694114, -0.05950863],
#        [ 0.06315433, -0.01703225, -0.10299951, ...,  0.08035325,
#         -0.00211691, -0.00334399]], dtype=float32)
#  array([[ 0.2237224 , -0.03468407, -0.3961007 , ...,  0.2835035 ,
#          0.01926391,  0.01888034],
#        [ 0.6343865 , -0.11976792, -0.94298124, ...,  0.7022181 ,
#          0.01484382, -0.03714199],
#        [ 0.41074246, -0.07937248, -0.6586139 , ...,  0.49525353,
#          0.01212853,  0.00137358],
#        ...,
#        [ 0.03793903, -0.0049526 , -0.05552595, ...,  0.04405589,
#          0.00297798,  0.00198896],
#        [ 0.3726301 , -0.06430519, -0.6046159 , ...,  0.44133472,
#          0.02374993, -0.00836478],
#        [ 0.49789566, -0.09443165, -0.7937232 , ...,  0.6182698 ,
#          0.00109857,  0.01282176]], dtype=float32)
#  array([[ 0.6763299 , -0.1250392 , -1.0158067 , ...,  0.75609875,
#          0.01116109, -0.03183101],
#        [ 0.73311186, -0.13326104, -1.0798547 , ...,  0.7854416 ,
#          0.05101532, -0.06657729],
#        [ 0.70029944, -0.13451599, -1.1198015 , ...,  0.8492055 ,
#          0.01483014, -0.003225  ],
#        ...,
#        [ 0.67186147, -0.12996183, -1.0746675 , ...,  0.8029338 ,
#          0.05694114, -0.05950863],
#        [ 0.10436954, -0.02366941, -0.17396978, ...,  0.12925604,
#          0.00129827,  0.00663045],
#        [ 0.08562155, -0.01937968, -0.1470253 , ...,  0.10931905,
#          0.01205767,  0.00194311]], dtype=float32)
#  array([[ 2.3436780e-01, -4.2576186e-02, -4.3872836e-01, ...,
#          3.1567171e-01,  1.9278185e-02,  1.9653352e-02],
#        [ 3.0165434e-01, -6.2124666e-02, -5.0451851e-01, ...,
#          3.6807087e-01,  1.7163755e-02,  9.6546821e-03],
#        [ 1.2669499e-01, -2.0009015e-02, -2.2053409e-01, ...,
#          1.6099803e-01,  2.7196300e-03,  9.0494063e-03],
#        ...,
#        [ 3.6424730e-02, -6.5779909e-03, -7.5572558e-02, ...,
#        [ 0.10258763, -0.01610517, -0.17900623, ...,  0.12809283,
#          0.00435884, -0.0006365 ],
#        [ 0.29007065, -0.05495877, -0.5109268 , ...,  0.37628183,
#          0.02624183,  0.00895957],
#        [ 0.24052502, -0.04081843, -0.40479356, ...,  0.2917479 ,
#          0.03009465, -0.00585925]], dtype=float32)
#  array([[ 5.77807426e-01, -1.14549398e-01, -9.06058967e-01, ...,
#          6.85313284e-01,  1.37366457e-02, -1.17869703e-02],
#        [ 4.82467115e-01, -9.75724906e-02, -8.06053102e-01, ...,
#          6.04408860e-01,  1.17318276e-02, -9.68918204e-04],
#        [ 3.94896626e-01, -1.20642617e-01, -1.08313358e+00, ...,
#          8.59604657e-01, -6.32892102e-02,  1.23527646e-01],
#        ...,
#        [ 3.09632365e-02, -6.57041371e-03, -6.06127158e-02, ...,
#          4.18628603e-02, -1.17458182e-03,  5.03045321e-03],
#        [ 8.60183313e-03, -3.80796939e-03, -7.32192211e-03, ...,
#          8.59944429e-03,  3.06583755e-03, -1.16162945e-03],
#        [ 3.47621716e-03,  5.74206351e-05, -1.00124106e-02, ...,
#          9.94210038e-03,  2.27647863e-04,  4.15030029e-03]], dtype=float32)
#  array([[ 6.89666033e-01, -1.13829784e-01, -1.02695811e+00, ...,
#          7.45532036e-01,  2.84878016e-02, -6.22944795e-02],
#        [ 4.01485443e-01, -7.70188645e-02, -6.32830679e-01, ...,
#          4.77194160e-01,  9.95465554e-03, -1.03120366e-03],
#        [ 4.97069478e-01, -9.96444896e-02, -7.85327077e-01, ...,
#          5.85608304e-01,  9.39631648e-03,  9.96319111e-04],
#        ...,
#        [ 5.96221387e-01, -1.12958662e-01, -9.51065719e-01, ...,
#          7.39890277e-01,  2.39146082e-03,  3.76792299e-03],
#        [ 2.03776583e-01, -3.63318250e-02, -3.45002383e-01, ...,
#          2.54315436e-01,  7.03963498e-03,  1.30678359e-02],
#        [ 1.19006582e-01, -2.39863805e-02, -1.98108152e-01, ...,
#          1.46609873e-01,  1.17378496e-02, -3.67096346e-03]], dtype=float32)
#  array([[ 0.09714051, -0.014655  , -0.16571929, ...,  0.12535356,
#          0.00474056,  0.0065959 ],
#        [ 0.04398393, -0.00938338, -0.07648814, ...,  0.05512369,
#          0.0018582 , -0.00295671],
#        [ 0.00953027, -0.00519062, -0.01830166, ...,  0.01550165,
#         -0.00226125,  0.00349302],
#        ...,
#        [ 0.6815649 , -0.12429286, -1.0327696 , ...,  0.78177613,
#          0.01586573, -0.03738726],
#        [ 0.297366  , -0.06137244, -0.4952768 , ...,  0.36738238,
#          0.01506168,  0.00473004],
#        [ 0.0503625 , -0.01401406, -0.09293016, ...,  0.06569625,
#          0.00612821,  0.006481  ]], dtype=float32)
#  array([[ 0.22456135, -0.0360447 , -0.39883777, ...,  0.289117  ,
#          0.02047195,  0.00739394],
#        [ 0.09883417, -0.02356912, -0.17317528, ...,  0.13264339,
#          0.00378922,  0.00772703],
#        [ 0.43371812, -0.07193066, -0.7271805 , ...,  0.5293021 ,
#          0.02827609, -0.00618578],
#        ...,
#        [ 0.63191396, -0.10209434, -0.9322493 , ...,  0.67396265,
#          0.04130398, -0.07123957],
#        [ 0.67186147, -0.12996183, -1.0746675 , ...,  0.8029338 ,
#          0.05694114, -0.05950863],
#        [ 0.13542387, -0.02422017, -0.20670462, ...,  0.1571195 ,
#          0.0096865 , -0.00141622]], dtype=float32)
#  array([[ 0.6007288 , -0.11275575, -0.9567567 , ...,  0.7302641 ,
#          0.00587467,  0.00292071],
#        [ 0.44017175, -0.07956386, -0.739969  , ...,  0.53970534,
#          0.03893362, -0.00213913],
#        [ 0.05735302, -0.01128778, -0.09244625, ...,  0.07312049,
#          0.0060057 ,  0.00297079],
#        ...,
#        [ 0.15088691, -0.02364691, -0.257254  , ...,  0.18656908,
#          0.00881984,  0.00501291],
#        [ 0.03290791, -0.01159184, -0.05780582, ...,  0.040663  ,
#         -0.00347402, -0.00264407],
#        [ 0.8016561 , -0.14009026, -0.9996229 , ...,  0.76565486,
#         -0.04942892, -0.11973654]], dtype=float32)
#  array([[ 0.1207206 , -0.01962333, -0.21861869, ...,  0.1586897 ,
#          0.00856112,  0.00474587],
#        [ 0.15741716, -0.02654832, -0.25526297, ...,  0.18567608,
#          0.00441246, -0.00465629],
#        [ 0.01322874,  0.00245489, -0.01932389, ...,  0.01571601,
#         -0.00169321, -0.0027679 ],
#        ...,
#        [ 0.06514487, -0.00816166, -0.13057311, ...,  0.09889315,
#          0.00891112,  0.00761681],
#        [ 0.01818777,  0.00191516, -0.02229253, ...,  0.01353121,
#         -0.00334543,  0.00194333],
#        [ 0.03390291, -0.00515735, -0.05112892, ...,  0.03847608,
#         -0.00192488,  0.00517979]], dtype=float32)
#  array([[ 0.6411545 , -0.11145582, -1.0084254 , ...,  0.76373845,
#          0.04335325, -0.02152833],
#        [ 0.6343865 , -0.11976792, -0.94298124, ...,  0.7022181 ,
#          0.01484382, -0.03714199],
#        [ 0.3729386 , -0.06617989, -0.6311236 , ...,  0.45814994,
#          0.03280872,  0.01531048],
#        ...,
#        [ 0.6471284 , -0.14212729, -1.0264348 , ...,  0.80870366,
#         -0.03414745,  0.03964431],
#        [ 0.17949413, -0.03119837, -0.307192  , ...,  0.22741137,
#          0.00628561,  0.00423987],
#        [ 0.24308544, -0.04901401, -0.40065062, ...,  0.29067272,
#          0.01368301,  0.0068691 ]], dtype=float32)
#  array([[ 0.25253156, -0.05019335, -0.43729645, ...,  0.32397106,
#          0.01934988,  0.00894181],
#        [ 0.16584384, -0.03213738, -0.29893005, ...,  0.21389487,
#          0.01028375,  0.0084367 ],
#        [ 0.32832453, -0.06050596, -0.5197054 , ...,  0.39112017,
#          0.01477217, -0.01211181],
#        ...,
#        [ 0.5962214 , -0.11295866, -0.9510657 , ...,  0.7398903 ,
#          0.00239146,  0.00376792],
#        [ 0.35099548, -0.06963587, -0.6024616 , ...,  0.44813567,
#          0.02522742,  0.00838614],
#        [ 0.7720352 , -0.1409573 , -0.95648897, ...,  0.728646  ,
#          0.00616093, -0.15335192]], dtype=float32)
#  array([[ 7.33111858e-01, -1.33261040e-01, -1.07985473e+00, ...,
#          7.85441577e-01,  5.10153249e-02, -6.65772930e-02],
#        [ 7.00299442e-01, -1.34515986e-01, -1.11980152e+00, ...,
#          8.49205494e-01,  1.48301432e-02, -3.22500058e-03],
#        [ 5.76941436e-03, -6.37969235e-03, -1.29432324e-02, ...,
#          1.28867105e-02,  4.48811520e-03, -2.74434197e-03],
#        ...,
#        [ 5.80471814e-01, -1.17849834e-01, -9.22288299e-01, ...,
#          7.03042567e-01,  1.43325236e-02,  2.71749892e-03],
#        [ 6.81564927e-01, -1.24292858e-01, -1.03276956e+00, ...,
#          7.81776130e-01,  1.58657338e-02, -3.73872593e-02],
#        [ 1.91115979e-02, -2.44691828e-03, -3.40677090e-02, ...,
#          2.65503507e-02, -2.34510706e-04,  6.92169939e-04]], dtype=float32)
# ...
#          3.4333277e-02, -9.0376521e-04, -2.6919192e-04]], dtype=float32)
#  array([[ 0.18104546, -0.0319221 , -0.30533788, ...,  0.23209009,
#          0.010616  ,  0.01312464],
#        [ 0.2237224 , -0.03468407, -0.3961007 , ...,  0.2835035 ,
#          0.01926391,  0.01888034],
#        [ 0.5910074 , -0.11390986, -0.9013216 , ...,  0.68574286,
#          0.00447635, -0.0190576 ],
#        ...,
#        [ 0.6815649 , -0.12429286, -1.0327696 , ...,  0.78177613,
#          0.01586573, -0.03738726],
#        [ 0.03939408, -0.00721884, -0.08938622, ...,  0.06289832,
#          0.01502129,  0.00285424],
#        [ 0.19275734, -0.02954668, -0.29869908, ...,  0.21200722,
#          0.0052052 , -0.01468077]], dtype=float32)
#  array([[ 0.60878843, -0.11408525, -0.91482747, ...,  0.67372924,
#          0.03119231, -0.04335431],
#        [ 0.23325257, -0.04196937, -0.41452575, ...,  0.3063141 ,
#          0.01971819,  0.00460831],
#        [ 0.7516801 , -0.12256238, -1.0587721 , ...,  0.7800866 ,
#          0.05215018, -0.07100074],
#        ...,
#        [ 0.046293  , -0.00867255, -0.0911064 , ...,  0.0703733 ,
#          0.00988194,  0.00476889],
#        [ 0.35099548, -0.06963587, -0.6024616 , ...,  0.44813567,
#          0.02522742,  0.00838614],
#        [ 0.7720352 , -0.1409573 , -0.95648897, ...,  0.728646  ,
#          0.00616093, -0.15335192]], dtype=float32)
#  array([[ 0.07363495, -0.01308482, -0.11892578, ...,  0.09061723,
#          0.00461245, -0.00252367],
#        [ 0.35748142, -0.06924076, -0.59420705, ...,  0.43547967,
#          0.03352366, -0.01309152],
#        [ 0.6763299 , -0.1250392 , -1.0158067 , ...,  0.75609875,
#          0.01116109, -0.03183101],
#        ...,
#        [ 0.39053354, -0.06944694, -0.6394522 , ...,  0.47765517,
#          0.02069478,  0.00469767],
#        [ 0.40360078, -0.08246367, -0.67933273, ...,  0.5023582 ,
#          0.01878528,  0.00822296],
#        [ 0.56107336, -0.11164133, -0.8804169 , ...,  0.66044694,
#          0.00829607, -0.01529546]], dtype=float32)
#  array([[ 0.21876076, -0.04174153, -0.38004822, ...,  0.28094378,
#          0.0120558 ,  0.00414455],
#        [ 0.70029944, -0.13451599, -1.1198015 , ...,  0.8492055 ,
#          0.01483014, -0.003225  ],
#        [ 0.6609321 , -0.12797694, -1.0951084 , ...,  0.82943434,
#          0.01840308,  0.02186589],
#        ...,
#        [ 0.6313984 , -0.11066405, -1.0157765 , ...,  0.754473  ,
#          0.03472825, -0.00927729],
#        [ 0.63191396, -0.10209434, -0.9322493 , ...,  0.67396265,
#          0.04130398, -0.07123957],
#        [ 0.67186147, -0.12996183, -1.0746675 , ...,  0.8029338 ,
#          0.05694114, -0.05950863]], dtype=float32)
#  array([[ 9.2116788e-02, -1.6266087e-02, -1.4838217e-01, ...,
#          1.0627316e-01,  4.0888535e-03, -1.2432463e-03],
#        [ 1.5929988e-01, -2.7530231e-02, -2.8594249e-01, ...,
#          2.1185035e-01,  1.2288283e-02,  8.3818501e-03],
#        [ 5.4648936e-01, -1.0554771e-01, -8.7299424e-01, ...,
#          6.5758073e-01,  1.1785234e-02, -2.4357140e-04],
#        ...,
#        [ 4.3458691e-01, -8.0354311e-02, -6.7799568e-01, ...,
#          5.0131571e-01,  3.6285454e-03, -1.4294238e-02],
#        [ 2.9514909e-02, -6.6014556e-03, -6.1807893e-02, ...,
#          4.5915648e-02,  4.7347350e-03,  5.8354908e-03],
#        [ 3.1794807e-01, -6.4920925e-02, -5.4270434e-01, ...,
#          4.0187562e-01,  1.6699286e-02,  8.9224074e-03]], dtype=float32)
#  array([[ 0.07505579, -0.0133391 , -0.12079848, ...,  0.08655624,
#          0.00444862,  0.00150483],
#        [ 0.1248595 , -0.01925471, -0.20414704, ...,  0.15278819,
#          0.00111963,  0.00159299],
#        [ 0.06376705, -0.00936516, -0.09143759, ...,  0.06439374,
#          0.00753699, -0.00123957],
#        ...,
#        [ 0.30281252, -0.06188773, -0.4977612 , ...,  0.37807304,
#          0.0106596 ,  0.00848837],
#        [ 0.67186147, -0.12996183, -1.0746675 , ...,  0.8029338 ,
#          0.05694114, -0.05950863],
#        [ 0.5962214 , -0.11295866, -0.9510657 , ...,  0.7398903 ,
#          0.00239146,  0.00376792]], dtype=float32)
#  array([[ 0.08654289, -0.01106177, -0.14321096, ...,  0.10842825,
#          0.0065129 ,  0.00560092],
#        [ 0.3952677 , -0.06664595, -0.6699945 , ...,  0.5054251 ,
#          0.0215031 ,  0.0179093 ],
#        [ 0.04055065, -0.01160014, -0.08408218, ...,  0.05817987,
#          0.00554196,  0.01115124],
#        ...,
#        [ 0.13719492, -0.02371791, -0.22061983, ...,  0.16416007,
#          0.00564509, -0.00562967],
#        [ 0.14581923, -0.02919307, -0.23604591, ...,  0.18166377,
#          0.00597724, -0.00193755],
#        [ 0.31794807, -0.06492092, -0.54270434, ...,  0.40187562,
#          0.01669929,  0.00892241]], dtype=float32)
#  array([[ 4.3485039e-01, -8.8770360e-02, -6.9082987e-01, ...,
#          5.1790416e-01,  2.0901177e-02, -6.4024460e-03],
#        [ 5.0702900e-01, -6.6216968e-02, -7.4391586e-01, ...,
#          4.4706216e-01,  1.5606405e-01, -1.3582879e-01],
#        [ 5.4648936e-01, -1.0554771e-01, -8.7299424e-01, ...,
#  array([[ 5.17366171e-01, -9.42239985e-02, -7.79666960e-01, ...,
#          5.83148956e-01,  6.14284445e-03, -2.42723078e-02],
#        [ 6.25498891e-01, -1.18715778e-01, -9.53835309e-01, ...,
#          7.09005892e-01,  1.01379035e-02, -2.77852472e-02],
#        [ 2.25669295e-01, -4.72487807e-02, -3.70352745e-01, ...,
#          2.71578431e-01,  7.49676675e-03, -3.44888656e-03],
#        ...,
#        [ 7.16609135e-02, -1.17487414e-02, -1.30820632e-01, ...,
#          8.88345763e-02,  6.50451938e-03,  2.40755908e-04],
#        [ 2.43085444e-01, -4.90140095e-02, -4.00650620e-01, ...,
#          2.90672719e-01,  1.36830099e-02,  6.86910143e-03],
#        [ 3.51723254e-01, -6.58506528e-02, -6.16671503e-01, ...,
#          4.56542164e-01,  1.96009390e-02,  2.71375664e-02]], dtype=float32)
#  array([[ 5.9084147e-01, -1.0929924e-01, -8.7404627e-01, ...,
#          6.5492606e-01,  2.3233324e-02, -5.4660253e-02],
#        [ 4.9721569e-01, -9.5473930e-02, -7.8458530e-01, ...,
#          5.8404803e-01,  1.1125411e-02, -1.1646717e-02],
#        [ 9.7680986e-03,  1.1356113e-03, -9.5250420e-03, ...,
#          8.6526303e-03, -1.6463218e-03,  2.2411048e-05],
#        ...,
#        [ 1.3662567e-02,  4.7448950e-04, -3.0087356e-02, ...,
#          1.9818787e-02,  2.1006474e-03,  5.6618131e-03],
#        [ 1.4556901e-01, -1.9896504e-02, -2.6372704e-01, ...,
#          1.9439204e-01,  1.6888481e-02,  8.2093058e-03],
#        [ 8.0165613e-01, -1.4009026e-01, -9.9962288e-01, ...,
#          7.6565486e-01, -4.9428925e-02, -1.1973654e-01]], dtype=float32)
#  array([[ 0.03455852, -0.01045011, -0.06074297, ...,  0.04379234,
#         -0.00115612,  0.00068367],
#        [ 0.35601458, -0.06489328, -0.5925644 , ...,  0.4415035 ,
#          0.01779363,  0.00855921],
#        [ 0.08734089, -0.01624307, -0.15736291, ...,  0.10856955,
#          0.00983611,  0.00170452],
#        ...,
#        [ 0.11615356, -0.02329474, -0.19759034, ...,  0.1452103 ,
#          0.0008489 ,  0.00189948],
#        [ 0.297366  , -0.06137244, -0.4952768 , ...,  0.36738238,
#          0.01506168,  0.00473004],
#        [ 0.40382814, -0.07732171, -0.6799239 , ...,  0.5076936 ,
#          0.02060179,  0.00135988]], dtype=float32)
#  array([[ 0.1207206 , -0.01962333, -0.21861869, ...,  0.1586897 ,
#          0.00856112,  0.00474587],
#        [ 0.68966603, -0.11382978, -1.0269581 , ...,  0.74553204,
#          0.0284878 , -0.06229448],
#        [ 0.6763299 , -0.1250392 , -1.0158067 , ...,  0.75609875,
#          0.01116109, -0.03183101],
#        ...,
#        [ 0.56107336, -0.11164133, -0.8804169 , ...,  0.66044694,
#          0.00829607, -0.01529546],
#        [ 0.36640316, -0.06652988, -0.62211734, ...,  0.450364  ,
#          0.02251724,  0.00441404],
#        [ 0.02519842, -0.00233144, -0.0548398 , ...,  0.0434999 ,
#          0.0048667 ,  0.00817633]], dtype=float32)
